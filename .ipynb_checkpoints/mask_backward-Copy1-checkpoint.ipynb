# %%
import numpy as np
import argparse
import os
import sys
import random
import torch
import torch.fft as F
from importlib import reload
from torch.nn.functional import relu
import torch.nn as nn
import torch.nn.functional as Func
import torch.optim as optim
import utils
import mask_backward_v4
import matplotlib.pyplot as plt
# from mask_backward_v1 import mask_backward, mask_eval
# from mask_backward_v2 import mask_backward, mask_eval
from mask_backward_v4 import mask_backward, mask_eval
from utils import *
from mnet import MNet
sys.path.insert(0,'/home/huangz78/mri/unet/')
from unet_model import UNet

torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %% [markdown]
# #### import data to test mask_backward function

# %%
# data_gt = np.load('/home/huangz78/data/data_gt.npz')
# datafornn = np.load('/home/huangz78/data/datafornn.npz')
data = np.load('/home/huangz78/data/traindata_x.npz')
dtyp = torch.float
xfull = torch.tensor(data['xfull'],dtype=dtyp)
fullmask = torch.tensor(data['mask']) # a random mask

# %% [markdown]
# ##### greedy mask and relevant data

# %%
from sklearn.model_selection import train_test_split

imgs   = torch.tensor( np.load('/home/huangz78/data/data_gt.npz')['imgdata'] ).permute(2,0,1)
masks  = torch.tensor( np.load('/home/huangz78/data/data_gt_greedymask.npz')['mask'].T ) # labels are already rolled
imgNum = imgs.shape[0]
traininds, testinds = train_test_split(np.arange(imgNum),random_state=0,shuffle=True,train_size=round(imgNum*0.8))

# %%
# reload(utils)
# from utils import hfen
reload(mask_backward_v3)
from mask_backward_v3 import mask_backward, mask_eval
# import unet_model
# reload(unet_model)
# from unet_model import UNet

# %%
corefreq = 8
budget = 32
mnet = MNet(beta=1,in_channels=2,out_size=320-corefreq, imgsize=(320,320),poolk=3)
# mnet.apply(weights_init)
mnet.eval()
### load a unet for maskbackward
# UNET = UNet(n_channels=1,n_classes=1,bilinear=True,skip=False)
# unetpath = '/home/huangz78/checkpoints/unet_'+ str(UNET.n_channels) +'.pth'
# unetpath = '/home/huangz78/checkpoints/unet_1_False.pth'

unet_skip = True
UNET = UNet(n_channels=1,n_classes=1,bilinear=(not unet_skip),skip=unet_skip)
unetpath = '/home/huangz78/checkpoints/unet_1_'+str(unet_skip)+'.pth'
checkpoint = torch.load(unetpath)
UNET.load_state_dict(checkpoint['model_state_dict'])
print('Unet loaded successfully from: ' + unetpath )
UNET.train()
print('nn\'s are ready')

# %%
# for (8,32) setting
maxIter_mb = 30
lr_mb      = 1e-2
print('preselect_num = ',corefreq)
print('budget = ',budget)

xstar = xfull[0,:,:].view(-1,320,320)
# xstar    = imgs[testinds[testinds.size//2:],:,:]
for ind in range(xstar.shape[0]):
    xstar[ind,:,:] = xstar[ind,:,:]/xstar[ind,:,:].max()

# base_eq = torch.flatten( torch.tensor( [[1,0] for i in range(budget//2)] ) )
# highmask = torch.zeros((320-corefreq))
# highmask[(320-corefreq - budget)//2:(320-corefreq+budget)//2] = base_eq
highmask = mask_filter(mask_naiveRand(320,fix=corefreq,other=1.5*budget,roll=True)[0],base=corefreq,roll=True)
highmask = highmask.view(-1,320-corefreq)

fullmask = mask_complete(highmask,320,dtyp=torch.float).view(-1)
kplot(fullmask,roll=False,img_name='random mask')

highmask_refined, _, mask_loss, init_mask_loss = mask_backward(highmask,xstar,unet=UNET, mnet=mnet,\
                  beta=1.,alpha=1e-4,c=1e-3,\
                  maxIter=maxIter_mb,seed=0,break_limit=np.inf,\
                  lr=lr_mb,mode='UNET',budget=budget,normalize=True,\
                  verbose=True,dtyp=torch.float,testmode='sigpy',hfen=True,return_loss_only=False,\
                  save_cp=False)

fullmask = mask_complete(highmask_refined,320,dtyp=torch.float).view(-1)
kplot(fullmask,roll=False,img_name='refined mask')

# %%
res_path = '/home/huangz78/checkpoints/mb_rec.npz'
res = np.load(res_path)
l2loss   = res['l2loss']
hfen     = res['hfen']
sparsity = res['sparsity']

# %%
# for (24,56) setting
mask_backward(highmask,xstar,unet=UNET, mnet=mnet,\
              beta=1.,alpha=10**(-9.5),c=1e-2,\
              maxIter=maxIter_mb,seed=0,break_limit=np.inf,\
              lr=lr_mb,mode='UNET',budget=budget,normalize=False,\
              verbose=True,dtyp=torch.float,testmode='sigpy',hfen=True,return_loss_only=True)

# %% [markdown]
# # 8-fold check

# %%
corefreq = 8
budget   = 32

mnet = MNet(beta=1,in_channels=2,out_size=320-corefreq, imgsize=(320,320),poolk=3)
# mnet.apply(weights_init)
mnet.eval()
print('mnet is randomly initialized by PyTorch default setting~')

# %%
xstar = xfull[0:5,:,:]
for ind in range(xstar.shape[0]):
    xstar[ind,:,:] = xstar[ind,:,:]/xstar[ind,:,:].max()

NN         = 9
# alpha_grid = 10**(np.array([-4,-3.5,-3,-2.5,-2]))
alpha_grid = 10**(np.linspace(-4.5,-3.7,NN))
# c_grid     = np.array([1e-4])
c_grid     = np.array([1e-4,1e-3,1e-2,1e-1])
print('alpha grid: ',alpha_grid)
print('c grid: ',c_grid)
l2loss   = np.zeros((NN,5))
hfen     = np.zeros((NN,5))
sparsity = np.zeros((NN,5))

maxIter_mb = 30
lr_mb      = 1e-2

unet_skip = True # unet n_channels = 1
# unet_skip = False # unet n_channels = 2

# %%
lowfreqmask = mask_naiveRand(xstar.shape[1],fix=corefreq,other=0,roll=True)[0]

yfull = torch.fft.fftshift(F.fftn(xstar,dim=(1,2),norm='ortho'),dim=(1,2)) # y is ROLLED!
y = torch.zeros((yfull.shape[0],2,yfull.shape[1],yfull.shape[2]),dtype=torch.float,device='cpu')
y[:,0,lowfreqmask==1,:] = torch.real(yfull)[:,lowfreqmask==1,:]
y[:,1,lowfreqmask==1,:] = torch.imag(yfull)[:,lowfreqmask==1,:]
highmask = torch.sigmoid( mnet(y) ).detach()

highmask = mask_makebinary(raw_normalize(highmask,budget,threshold=0.5),threshold=0.5,sigma=False)

# %%
fullmask = mask_complete(highmask,320)
kplot(fullmask[0,:])

# %%
# highmask = mask_filter(mask_naiveRand(320,fix=corefreq,other=1.5*budget,roll=True)[0],base=corefreq,roll=True)
# highmask = highmask.repeat(5,1)

c_ind = 0
for c in c_grid:
    print(f'c_ind {c_ind+1} out of {len(c_grid)}')
    a_ind = 0
    for alpha in alpha_grid:
        print(f'alpha_ind {a_ind+1} out of {len(alpha_grid)}')
        # load a unet for maskbackward
#         UNET = UNet(n_channels=2,n_classes=1,bilinear=(not unet_skip),skip=unet_skip)
#         unetpath = '/home/huangz78/checkpoints/unet_2_'+str(unet_skip)+'.pt'
        UNET = UNet(n_channels=1,n_classes=1,bilinear=(not unet_skip),skip=unet_skip)
        unetpath = '/home/huangz78/checkpoints/unet_1_'+str(unet_skip)+'.pth'
        checkpoint = torch.load(unetpath)
        UNET.load_state_dict(checkpoint['model_state_dict'])
        print('Unet loaded successfully from: ' + unetpath )
        UNET.train()
        (l2loss[a_ind,c_ind],hfen[a_ind,c_ind]),sparsity[a_ind,c_ind] =\
                        mask_backward(highmask,xstar,unet=UNET, mnet=mnet,\
                          beta=1.,alpha=alpha,c=c,\
                          maxIter=maxIter_mb,seed=0,break_limit=np.inf,\
                          lr=lr_mb,mode='UNET',budget=budget,normalize=False,\
                          dtyp=torch.float,verbose=True,testmode='sigpy',hfen=True,\
                          return_loss_only=True)
        a_ind += 1
    print('\n')
    c_ind += 1

# %%
# highmask = sigmoid_binarize(raw_normalize(mnet(z),budget=budget))
randmask = torch.zeros(highmask.shape)
for ind in range(highmask.shape[0]):
    sampinds = np.random.choice(highmask.shape[1],budget,replace=False)
    randmask[ind,sampinds] = 1
lowfmask,_,_ = mask_naiveRand(xstar.shape[1]-corefreq,fix=budget,other=0,roll=True)
lowfmask = lowfmask.repeat(highmask.shape[0],1)

# %%
# full_highmask = mask_complete(highmask,320)
full_randmask = mask_complete(randmask,320)
full_lowfmask = mask_complete(lowfmask,320)

(rand_l2,rand_hfen) = mask_eval(full_randmask,xstar,mode='sigpy',hfen=True)
(lowf_l2,lowf_hfen) = mask_eval(full_lowfmask,xstar,mode='sigpy',hfen=True)
# (gred_l2,gred_hfen) = mask_eval(full_gredmask.to(torch.float),xstar,mode='sigpy',hfen=True)
print('mode = sigpy')

print(rand_l2)
print(lowf_l2)
# print(gred_l2)

# %%
np.log10(alpha_grid[2])

# %%
markers = ['H', 'D', 'P', 'X','+']
plt.figure(figsize=(10,8))
for c_ind in range(len(c_grid)):
    plt.plot(alpha_grid,l2loss[:,c_ind],label='c='+str(c_grid[c_ind]),marker=markers[c_ind],markersize=7)
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*rand_l2,color='r',label='rand',linestyle = 'dotted')
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*lowf_l2,color='g',label='low freq.',linestyle = 'dotted')
plt.title('l2 loss of masks')
plt.xlabel('alpha')
plt.xscale('log')
plt.legend(loc='best')

plt.figure(figsize=(10,8))
for c_ind in range(len(c_grid)):
    plt.plot(alpha_grid,hfen[:,c_ind],label='c='+str(c_grid[c_ind]),marker=markers[c_ind],markersize=7)
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*rand_hfen,color='r',label='rand',linestyle = 'dotted')
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*lowf_hfen,color='g',label='low freq.',linestyle = 'dotted')
plt.title('HFEN of masks')
plt.xscale('log')
plt.legend(loc='best')

plt.figure(figsize=(10,8))
for c_ind in range(len(c_grid)):
    plt.plot(alpha_grid,sparsity[:,c_ind],label='c='+str(c_grid[c_ind]),marker=markers[c_ind],markersize=7)
plt.plot(alpha_grid,(corefreq+budget)/320*np.ones(alpha_grid.shape),'-.',label='target')
plt.title('mask sparsity')
plt.xscale('log')
plt.legend(loc='best')
plt.xlabel('alpha')

# %% [markdown]
# # 4-fold check

# %%
corefreq = 16
budget   = 64
from mnet import MNet
mnet = MNet(beta=1,in_channels=2,out_size=320-corefreq, imgsize=(320,320),poolk=3)
# mnet.apply(weights_init)
mnet.eval()
print('mnet is initialized')
# Out:
# mnet is initialized

# %%
xstar = xfull[0:5,:,:]
for ind in range(xstar.shape[0]):
    xstar[ind,:,:] = xstar[ind,:,:]/xstar[ind,:,:].max()

NN         = 9
alpha_grid = 10**(np.linspace(-5.5,-4.5,NN))
c_grid     = np.array([1e-4,1e-3,1e-2,1e-1])

l2loss   = np.zeros((NN,5))
hfen     = np.zeros((NN,5))
sparsity = np.zeros((NN,5))

maxIter_mb = 30
lr_mb      = 1e-2

unet_skip = True

# %%
lowfreqmask = mask_naiveRand(xstar.shape[1],fix=corefreq,other=0,roll=True)[0]

yfull = torch.fft.fftshift(F.fftn(xstar,dim=(1,2),norm='ortho'),dim=(1,2)) # y is ROLLED!
y = torch.zeros((yfull.shape[0],2,yfull.shape[1],yfull.shape[2]),dtype=torch.float,device='cpu')
y[:,0,lowfreqmask==1,:] = torch.real(yfull)[:,lowfreqmask==1,:]
y[:,1,lowfreqmask==1,:] = torch.imag(yfull)[:,lowfreqmask==1,:]
highmask = torch.sigmoid( mnet(y) ).detach()

highmask = mask_makebinary(raw_normalize(highmask,budget,threshold=0.5),threshold=0.5,sigma=False)

fullmask = mask_complete(highmask,320)
kplot(fullmask[0,:])
# Out:
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448224956/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
# highmask = mask_filter(mask_naiveRand(320,fix=corefreq,other=1.5*budget,roll=True)[0],base=corefreq,roll=True)
# highmask = highmask.repeat(5,1)

c_ind = 0
for c in c_grid:
    print(f'c_ind {c_ind+1} out of {len(c_grid)}')
    a_ind = 0
    for alpha in alpha_grid:
        print(f'alpha_ind {a_ind+1} out of {len(alpha_grid)}')
        # load a unet for maskbackward
        UNET = UNet(n_channels=1,n_classes=1,bilinear=True,skip=False)
        unetpath = '/home/huangz78/checkpoints/unet_1_False.pth'
        checkpoint = torch.load(unetpath)
        UNET.load_state_dict(checkpoint['model_state_dict'])
        UNET.train()
    # highmask_refined,unet = mask_backward(highmask,xstar,unet=UNET, mnet=mnet,\
    #                   beta=1.,alpha=alpha,c=c,\
    #                   maxIter=maxIter_mb,seed=0,break_limit=maxIter_mb*3//5,\
    #                   lr=lr_mb,mode='UNET',budget=budget,normalize=False,\
    #                   verbose=True,dtyp=torch.float)
        (l2loss[a_ind,c_ind],hfen[a_ind,c_ind]),sparsity[a_ind,c_ind] =\
                        mask_backward(highmask,xstar,unet=UNET, mnet=mnet,\
                          beta=1.,alpha=alpha,c=c,\
                          maxIter=maxIter_mb,seed=0,break_limit=np.inf,\
                          lr=lr_mb,mode='UNET',budget=budget,normalize=False,\
                          dtyp=torch.float,verbose=True,testmode='sigpy',hfen=True,\
                          return_loss_only=True)
        a_ind += 1
    print('\n')
    c_ind += 1
# Out:
# c_ind 1 out of 4
# alpha_ind 1 out of 9
# loss of the input mask:  (0.11267458945512772, 0.7367445230484009)
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/autograd/__init__.py:149: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448224956/work/aten/src/ATen/native/Copy.cpp:240.)
#   allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# Iter 2, rows added: 0.0, rows reducted: 34.2, current samp. ratio: 0.143125
# Iter 3, rows added: 4.8, rows reducted: 3.2, current samp. ratio: 0.148125
# Iter 4, rows added: 24.2, rows reducted: 6.0, current samp. ratio: 0.205
# Iter 5, rows added: 10.0, rows reducted: 12.4, current samp. ratio: 0.1975
# Iter 6, rows added: 12.2, rows reducted: 5.6, current samp. ratio: 0.218125
# Iter 7, rows added: 10.8, rows reducted: 5.2, current samp. ratio: 0.235625
# Iter 8, rows added: 8.4, rows reducted: 3.2, current samp. ratio: 0.251875
# Iter 9, rows added: 3.6, rows reducted: 3.8, current samp. ratio: 0.25125
# Iter 10, rows added: 11.0, rows reducted: 2.8, current samp. ratio: 0.276875
# Iter 11, rows added: 8.6, rows reducted: 4.0, current samp. ratio: 0.29125
# Iter 12, rows added: 9.4, rows reducted: 4.0, current samp. ratio: 0.308125
# Iter 13, rows added: 5.4, rows reducted: 3.8, current samp. ratio: 0.313125
# Iter 14, rows added: 8.6, rows reducted: 2.2, current samp. ratio: 0.333125
# Iter 15, rows added: 6.6, rows reducted: 4.4, current samp. ratio: 0.34
# Iter 16, rows added: 7.2, rows reducted: 3.6, current samp. ratio: 0.35125
# Iter 17, rows added: 7.0, rows reducted: 1.2, current samp. ratio: 0.369375
# Iter 18, rows added: 7.4, rows reducted: 3.6, current samp. ratio: 0.38125
# Iter 19, rows added: 7.6, rows reducted: 2.0, current samp. ratio: 0.39875
# Iter 20, rows added: 7.4, rows reducted: 3.2, current samp. ratio: 0.411875
# Iter 21, rows added: 6.0, rows reducted: 1.4, current samp. ratio: 0.42625
# Iter 22, rows added: 8.8, rows reducted: 2.8, current samp. ratio: 0.445
# Iter 23, rows added: 6.4, rows reducted: 1.2, current samp. ratio: 0.46125
# Iter 24, rows added: 6.6, rows reducted: 1.8, current samp. ratio: 0.47625
# Iter 25, rows added: 5.4, rows reducted: 1.6, current samp. ratio: 0.488125
# Iter 26, rows added: 7.0, rows reducted: 1.2, current samp. ratio: 0.50625
# Iter 27, rows added: 5.2, rows reducted: 2.4, current samp. ratio: 0.515
# Iter 28, rows added: 6.0, rows reducted: 1.0, current samp. ratio: 0.530625
# Iter 29, rows added: 6.4, rows reducted: 1.0, current samp. ratio: 0.5475
# Iter 30, rows added: 3.4, rows reducted: 0.8, current samp. ratio: 0.555625
#
# return at Iter ind:  30
# samp. ratio: 0.555625, loss of returned mask: (0.05227381139993668, 0.2699075222015381)
#
# alpha_ind 2 out of 9
# loss of the input mask:  (0.11267452239990235, 0.7367440223693847)
# Iter 2, rows added: 0.0, rows reducted: 35.6, current samp. ratio: 0.13875
# Iter 3, rows added: 3.6, rows reducted: 3.8, current samp. ratio: 0.138125
# Iter 4, rows added: 19.2, rows reducted: 5.0, current samp. ratio: 0.1825
# Iter 5, rows added: 7.6, rows reducted: 11.2, current samp. ratio: 0.17125
# Iter 6, rows added: 10.4, rows reducted: 4.2, current samp. ratio: 0.190625
# Iter 7, rows added: 7.4, rows reducted: 6.6, current samp. ratio: 0.193125
# Iter 8, rows added: 9.4, rows reducted: 2.6, current samp. ratio: 0.214375
# Iter 9, rows added: 5.2, rows reducted: 2.6, current samp. ratio: 0.2225
# Iter 10, rows added: 9.8, rows reducted: 5.4, current samp. ratio: 0.23625
# Iter 11, rows added: 9.2, rows reducted: 1.4, current samp. ratio: 0.260625
# Iter 12, rows added: 5.6, rows reducted: 3.0, current samp. ratio: 0.26875
# Iter 13, rows added: 6.0, rows reducted: 1.4, current samp. ratio: 0.283125
# Iter 14, rows added: 4.0, rows reducted: 2.6, current samp. ratio: 0.2875
# Iter 15, rows added: 7.4, rows reducted: 0.8, current samp. ratio: 0.308125
# Iter 16, rows added: 3.4, rows reducted: 1.2, current samp. ratio: 0.315
# Iter 17, rows added: 4.2, rows reducted: 0.8, current samp. ratio: 0.325625
# Iter 18, rows added: 3.6, rows reducted: 2.0, current samp. ratio: 0.330625
# Iter 19, rows added: 5.6, rows reducted: 3.2, current samp. ratio: 0.338125
# Iter 20, rows added: 6.4, rows reducted: 0.2, current samp. ratio: 0.3575
# Iter 21, rows added: 5.8, rows reducted: 2.0, current samp. ratio: 0.369375
# Iter 22, rows added: 4.8, rows reducted: 0.4, current samp. ratio: 0.383125
# Iter 23, rows added: 5.6, rows reducted: 1.0, current samp. ratio: 0.3975
# Iter 24, rows added: 6.2, rows reducted: 0.4, current samp. ratio: 0.415625
# Iter 25, rows added: 6.6, rows reducted: 2.2, current samp. ratio: 0.429375
# Iter 26, rows added: 6.0, rows reducted: 1.6, current samp. ratio: 0.443125
# Iter 27, rows added: 6.6, rows reducted: 0.8, current samp. ratio: 0.46125
# Iter 28, rows added: 2.6, rows reducted: 1.6, current samp. ratio: 0.464375
# Iter 29, rows added: 5.0, rows reducted: 0.2, current samp. ratio: 0.479375
# Iter 30, rows added: 1.8, rows reducted: 2.0, current samp. ratio: 0.47875
#
# return at Iter ind:  30
# samp. ratio: 0.47875, loss of returned mask: (0.05859416201710701, 0.3487936079502106)
#
# alpha_ind 3 out of 9
# loss of the input mask:  (0.11267459988594056, 0.7367446303367615)
# Iter 2, rows added: 0.0, rows reducted: 37.0, current samp. ratio: 0.134375
# Iter 3, rows added: 3.6, rows reducted: 4.0, current samp. ratio: 0.133125
# Iter 4, rows added: 16.2, rows reducted: 4.6, current samp. ratio: 0.169375
# Iter 5, rows added: 6.6, rows reducted: 8.8, current samp. ratio: 0.1625
# Iter 6, rows added: 7.8, rows reducted: 2.8, current samp. ratio: 0.178125
# Iter 7, rows added: 8.2, rows reducted: 5.0, current samp. ratio: 0.188125
# Iter 8, rows added: 9.4, rows reducted: 2.4, current samp. ratio: 0.21
# Iter 9, rows added: 4.8, rows reducted: 4.8, current samp. ratio: 0.21
# Iter 10, rows added: 6.4, rows reducted: 1.8, current samp. ratio: 0.224375
# Iter 11, rows added: 4.6, rows reducted: 3.2, current samp. ratio: 0.22875
# Iter 12, rows added: 6.6, rows reducted: 2.2, current samp. ratio: 0.2425
# Iter 13, rows added: 2.2, rows reducted: 6.2, current samp. ratio: 0.23
# Iter 14, rows added: 7.2, rows reducted: 0.2, current samp. ratio: 0.251875
# Iter 15, rows added: 4.4, rows reducted: 1.8, current samp. ratio: 0.26
# Iter 16, rows added: 6.4, rows reducted: 0.6, current samp. ratio: 0.278125
# Iter 17, rows added: 6.0, rows reducted: 0.8, current samp. ratio: 0.294375
# Iter 18, rows added: 4.4, rows reducted: 1.4, current samp. ratio: 0.30375
# Iter 19, rows added: 4.8, rows reducted: 1.6, current samp. ratio: 0.31375
# Iter 20, rows added: 4.4, rows reducted: 3.2, current samp. ratio: 0.3175
# Iter 21, rows added: 4.4, rows reducted: 0.0, current samp. ratio: 0.33125
# Iter 22, rows added: 5.4, rows reducted: 1.2, current samp. ratio: 0.344375
# Iter 23, rows added: 6.0, rows reducted: 1.6, current samp. ratio: 0.358125
# Iter 24, rows added: 7.4, rows reducted: 1.2, current samp. ratio: 0.3775
# Iter 25, rows added: 5.2, rows reducted: 1.2, current samp. ratio: 0.39
# Iter 26, rows added: 4.8, rows reducted: 2.0, current samp. ratio: 0.39875
# Iter 27, rows added: 4.0, rows reducted: 1.8, current samp. ratio: 0.405625
# Iter 28, rows added: 6.0, rows reducted: 1.2, current samp. ratio: 0.420625
# Iter 29, rows added: 5.6, rows reducted: 1.2, current samp. ratio: 0.434375
# Iter 30, rows added: 5.8, rows reducted: 0.6, current samp. ratio: 0.450625
#
# return at Iter ind:  30
# samp. ratio: 0.450625, loss of returned mask: (0.06118738800287247, 0.38405774235725404)
#
# alpha_ind 4 out of 9
# loss of the input mask:  (0.11267459988594056, 0.7367446541786193)
# Iter 2, rows added: 0.0, rows reducted: 39.2, current samp. ratio: 0.1275
# Iter 3, rows added: 2.8, rows reducted: 4.4, current samp. ratio: 0.1225
# Iter 4, rows added: 8.4, rows reducted: 4.4, current samp. ratio: 0.135
# Iter 5, rows added: 7.0, rows reducted: 5.4, current samp. ratio: 0.14
# Iter 6, rows added: 8.4, rows reducted: 3.4, current samp. ratio: 0.155625
# Iter 7, rows added: 7.8, rows reducted: 3.8, current samp. ratio: 0.168125
# Iter 8, rows added: 8.8, rows reducted: 2.6, current samp. ratio: 0.1875
# Iter 9, rows added: 4.6, rows reducted: 2.2, current samp. ratio: 0.195
# Iter 10, rows added: 5.0, rows reducted: 5.4, current samp. ratio: 0.19375
# Iter 11, rows added: 6.8, rows reducted: 1.0, current samp. ratio: 0.211875
# Iter 12, rows added: 4.8, rows reducted: 2.4, current samp. ratio: 0.219375
# Iter 13, rows added: 4.6, rows reducted: 3.2, current samp. ratio: 0.22375
# Iter 14, rows added: 4.2, rows reducted: 3.0, current samp. ratio: 0.2275
# Iter 15, rows added: 5.2, rows reducted: 1.2, current samp. ratio: 0.24
# Iter 16, rows added: 4.2, rows reducted: 1.4, current samp. ratio: 0.24875
# Iter 17, rows added: 4.4, rows reducted: 0.2, current samp. ratio: 0.261875
# Iter 18, rows added: 5.4, rows reducted: 1.2, current samp. ratio: 0.275
# Iter 19, rows added: 1.6, rows reducted: 2.0, current samp. ratio: 0.27375
# Iter 20, rows added: 4.0, rows reducted: 0.2, current samp. ratio: 0.285625
# Iter 21, rows added: 3.8, rows reducted: 2.4, current samp. ratio: 0.29
# Iter 22, rows added: 5.2, rows reducted: 0.4, current samp. ratio: 0.305
# Iter 23, rows added: 1.8, rows reducted: 0.8, current samp. ratio: 0.308125
# Iter 24, rows added: 3.0, rows reducted: 0.2, current samp. ratio: 0.316875
# Iter 25, rows added: 3.4, rows reducted: 1.0, current samp. ratio: 0.324375
# Iter 26, rows added: 4.4, rows reducted: 0.4, current samp. ratio: 0.336875
# Iter 27, rows added: 3.8, rows reducted: 2.4, current samp. ratio: 0.34125
# Iter 28, rows added: 4.2, rows reducted: 1.0, current samp. ratio: 0.35125
# Iter 29, rows added: 6.4, rows reducted: 1.0, current samp. ratio: 0.368125
# Iter 30, rows added: 4.6, rows reducted: 1.0, current samp. ratio: 0.379375
#
# return at Iter ind:  30
# samp. ratio: 0.37937499999999996, loss of returned mask: (0.06842277497053147, 0.4694605886936188)
#
# alpha_ind 5 out of 9
# loss of the input mask:  (0.11267461031675338, 0.7367446780204773)
# Iter 2, rows added: 0.0, rows reducted: 42.0, current samp. ratio: 0.11875
# Iter 3, rows added: 3.0, rows reducted: 5.0, current samp. ratio: 0.1125
# Iter 4, rows added: 6.8, rows reducted: 4.0, current samp. ratio: 0.12125
# Iter 5, rows added: 3.6, rows reducted: 5.0, current samp. ratio: 0.116875
# Iter 6, rows added: 6.2, rows reducted: 2.6, current samp. ratio: 0.128125
# Iter 7, rows added: 9.0, rows reducted: 3.8, current samp. ratio: 0.144375
# Iter 8, rows added: 7.6, rows reducted: 3.6, current samp. ratio: 0.156875
# Iter 9, rows added: 6.4, rows reducted: 0.6, current samp. ratio: 0.175
# Iter 10, rows added: 7.2, rows reducted: 0.2, current samp. ratio: 0.196875
# Iter 11, rows added: 2.6, rows reducted: 2.8, current samp. ratio: 0.19625
# Iter 12, rows added: 5.2, rows reducted: 4.6, current samp. ratio: 0.198125
# Iter 13, rows added: 3.2, rows reducted: 3.2, current samp. ratio: 0.198125
# Iter 14, rows added: 6.6, rows reducted: 3.4, current samp. ratio: 0.208125
# Iter 15, rows added: 5.2, rows reducted: 1.6, current samp. ratio: 0.219375
# Iter 16, rows added: 4.4, rows reducted: 1.6, current samp. ratio: 0.228125
# Iter 17, rows added: 3.0, rows reducted: 1.2, current samp. ratio: 0.23375
# Iter 18, rows added: 2.8, rows reducted: 1.4, current samp. ratio: 0.238125
# Iter 19, rows added: 4.8, rows reducted: 0.6, current samp. ratio: 0.25125
# Iter 20, rows added: 4.4, rows reducted: 0.4, current samp. ratio: 0.26375
# Iter 21, rows added: 2.0, rows reducted: 0.8, current samp. ratio: 0.2675
# Iter 22, rows added: 3.0, rows reducted: 0.8, current samp. ratio: 0.274375
# Iter 23, rows added: 3.0, rows reducted: 1.2, current samp. ratio: 0.28
# Iter 24, rows added: 4.2, rows reducted: 0.8, current samp. ratio: 0.290625
# Iter 25, rows added: 3.0, rows reducted: 0.6, current samp. ratio: 0.298125
# Iter 26, rows added: 3.0, rows reducted: 0.0, current samp. ratio: 0.3075
# Iter 27, rows added: 1.8, rows reducted: 0.8, current samp. ratio: 0.310625
# Iter 28, rows added: 1.4, rows reducted: 0.4, current samp. ratio: 0.31375
# Iter 29, rows added: 2.2, rows reducted: 1.0, current samp. ratio: 0.3175
# Iter 30, rows added: 2.2, rows reducted: 1.2, current samp. ratio: 0.320625
#
# return at Iter ind:  30
# samp. ratio: 0.320625, loss of returned mask: (0.07512636929750442, 0.5478506565093995)
#
# alpha_ind 6 out of 9
# loss of the input mask:  (0.11267455369234085, 0.7367442965507507)
# Iter 2, rows added: 0.0, rows reducted: 45.8, current samp. ratio: 0.106875
# Iter 3, rows added: 2.4, rows reducted: 3.6, current samp. ratio: 0.103125
# Iter 4, rows added: 5.8, rows reducted: 3.4, current samp. ratio: 0.110625
# Iter 5, rows added: 3.4, rows reducted: 5.0, current samp. ratio: 0.105625
# Iter 6, rows added: 5.6, rows reducted: 3.0, current samp. ratio: 0.11375
# Iter 7, rows added: 2.8, rows reducted: 2.0, current samp. ratio: 0.11625
# Iter 8, rows added: 4.8, rows reducted: 3.0, current samp. ratio: 0.121875
# Iter 9, rows added: 3.8, rows reducted: 3.2, current samp. ratio: 0.12375
# Iter 10, rows added: 10.2, rows reducted: 1.0, current samp. ratio: 0.1525
# Iter 11, rows added: 4.6, rows reducted: 6.2, current samp. ratio: 0.1475
# Iter 12, rows added: 10.8, rows reducted: 2.4, current samp. ratio: 0.17375
# Iter 13, rows added: 4.6, rows reducted: 2.2, current samp. ratio: 0.18125
# Iter 14, rows added: 7.0, rows reducted: 2.6, current samp. ratio: 0.195
# Iter 15, rows added: 3.4, rows reducted: 0.8, current samp. ratio: 0.203125
# Iter 16, rows added: 3.0, rows reducted: 1.8, current samp. ratio: 0.206875
# Iter 17, rows added: 2.8, rows reducted: 0.0, current samp. ratio: 0.215625
# Iter 18, rows added: 2.4, rows reducted: 1.6, current samp. ratio: 0.218125
# Iter 19, rows added: 5.6, rows reducted: 0.2, current samp. ratio: 0.235
# Iter 20, rows added: 4.8, rows reducted: 2.6, current samp. ratio: 0.241875
# Iter 21, rows added: 3.6, rows reducted: 0.4, current samp. ratio: 0.251875
# Iter 22, rows added: 2.8, rows reducted: 1.4, current samp. ratio: 0.25625
# Iter 23, rows added: 2.0, rows reducted: 1.4, current samp. ratio: 0.258125
# Iter 24, rows added: 3.0, rows reducted: 0.8, current samp. ratio: 0.265
# Iter 25, rows added: 1.6, rows reducted: 1.2, current samp. ratio: 0.26625
# Iter 26, rows added: 4.2, rows reducted: 1.4, current samp. ratio: 0.275
# Iter 27, rows added: 3.4, rows reducted: 1.2, current samp. ratio: 0.281875
# Iter 28, rows added: 4.2, rows reducted: 1.6, current samp. ratio: 0.29
# Iter 29, rows added: 2.8, rows reducted: 1.6, current samp. ratio: 0.29375
# Iter 30, rows added: 4.0, rows reducted: 2.4, current samp. ratio: 0.29875
#
# return at Iter ind:  30
# samp. ratio: 0.29875, loss of returned mask: (0.08062888383865356, 0.5734931230545044)
#
# alpha_ind 7 out of 9
# loss of the input mask:  (0.11267465054988861, 0.7367449522018432)
# Iter 2, rows added: 0.0, rows reducted: 48.8, current samp. ratio: 0.0975
# Iter 3, rows added: 2.0, rows reducted: 3.2, current samp. ratio: 0.09375
# Iter 4, rows added: 4.2, rows reducted: 4.8, current samp. ratio: 0.091875
# Iter 5, rows added: 2.8, rows reducted: 3.0, current samp. ratio: 0.09125
# Iter 6, rows added: 4.0, rows reducted: 1.4, current samp. ratio: 0.099375
# Iter 7, rows added: 3.8, rows reducted: 2.6, current samp. ratio: 0.103125
# Iter 8, rows added: 8.2, rows reducted: 2.8, current samp. ratio: 0.12
# Iter 9, rows added: 3.6, rows reducted: 4.0, current samp. ratio: 0.11875
# Iter 10, rows added: 8.8, rows reducted: 2.8, current samp. ratio: 0.1375
# Iter 11, rows added: 6.2, rows reducted: 3.8, current samp. ratio: 0.145
# Iter 12, rows added: 10.0, rows reducted: 2.2, current samp. ratio: 0.169375
# Iter 13, rows added: 3.0, rows reducted: 1.8, current samp. ratio: 0.173125
# Iter 14, rows added: 3.8, rows reducted: 4.6, current samp. ratio: 0.170625
# Iter 15, rows added: 6.0, rows reducted: 0.0, current samp. ratio: 0.189375
# Iter 16, rows added: 2.8, rows reducted: 3.6, current samp. ratio: 0.186875
# Iter 17, rows added: 4.6, rows reducted: 0.4, current samp. ratio: 0.2
# Iter 18, rows added: 1.6, rows reducted: 1.2, current samp. ratio: 0.20125
# Iter 19, rows added: 3.6, rows reducted: 0.2, current samp. ratio: 0.211875
# Iter 20, rows added: 2.2, rows reducted: 1.8, current samp. ratio: 0.213125
# Iter 21, rows added: 4.2, rows reducted: 0.4, current samp. ratio: 0.225
# Iter 22, rows added: 2.8, rows reducted: 3.0, current samp. ratio: 0.224375
# Iter 23, rows added: 5.2, rows reducted: 1.0, current samp. ratio: 0.2375
# Iter 24, rows added: 1.8, rows reducted: 2.2, current samp. ratio: 0.23625
# Iter 25, rows added: 3.0, rows reducted: 1.2, current samp. ratio: 0.241875
# Iter 26, rows added: 2.2, rows reducted: 0.4, current samp. ratio: 0.2475
# Iter 27, rows added: 1.4, rows reducted: 0.8, current samp. ratio: 0.249375
# Iter 28, rows added: 3.6, rows reducted: 1.2, current samp. ratio: 0.256875
# Iter 29, rows added: 2.2, rows reducted: 0.2, current samp. ratio: 0.263125
# Iter 30, rows added: 2.0, rows reducted: 2.6, current samp. ratio: 0.26125
#
# return at Iter ind:  30
# samp. ratio: 0.26125, loss of returned mask: (0.08356331586837769, 0.61644127368927)
#
# alpha_ind 8 out of 9
# loss of the input mask:  (0.1126745730638504, 0.7367444038391113)
# Iter 2, rows added: 0.0, rows reducted: 51.6, current samp. ratio: 0.08875
# Iter 3, rows added: 1.8, rows reducted: 4.2, current samp. ratio: 0.08125
# Iter 4, rows added: 3.6, rows reducted: 3.0, current samp. ratio: 0.083125
# Iter 5, rows added: 1.8, rows reducted: 2.8, current samp. ratio: 0.08
# Iter 6, rows added: 3.8, rows reducted: 2.2, current samp. ratio: 0.085
# Iter 7, rows added: 3.6, rows reducted: 1.4, current samp. ratio: 0.091875
# Iter 8, rows added: 2.2, rows reducted: 1.4, current samp. ratio: 0.094375
# Iter 9, rows added: 2.8, rows reducted: 2.0, current samp. ratio: 0.096875
# Iter 10, rows added: 5.4, rows reducted: 1.6, current samp. ratio: 0.10875
# Iter 11, rows added: 5.6, rows reducted: 0.8, current samp. ratio: 0.12375
# Iter 12, rows added: 5.0, rows reducted: 1.8, current samp. ratio: 0.13375
# Iter 13, rows added: 4.6, rows reducted: 1.2, current samp. ratio: 0.144375
# Iter 14, rows added: 5.4, rows reducted: 1.2, current samp. ratio: 0.1575
# Iter 15, rows added: 5.0, rows reducted: 0.4, current samp. ratio: 0.171875
# Iter 16, rows added: 3.4, rows reducted: 5.6, current samp. ratio: 0.165
# Iter 17, rows added: 6.2, rows reducted: 1.8, current samp. ratio: 0.17875
# Iter 18, rows added: 3.6, rows reducted: 1.2, current samp. ratio: 0.18625
# Iter 19, rows added: 2.0, rows reducted: 2.4, current samp. ratio: 0.185
# Iter 20, rows added: 4.2, rows reducted: 1.4, current samp. ratio: 0.19375
# Iter 21, rows added: 2.4, rows reducted: 0.6, current samp. ratio: 0.199375
# Iter 22, rows added: 2.2, rows reducted: 2.2, current samp. ratio: 0.199375
# Iter 23, rows added: 2.8, rows reducted: 1.8, current samp. ratio: 0.2025
# Iter 24, rows added: 3.4, rows reducted: 2.6, current samp. ratio: 0.205
# Iter 25, rows added: 3.4, rows reducted: 0.8, current samp. ratio: 0.213125
# Iter 26, rows added: 2.6, rows reducted: 4.4, current samp. ratio: 0.2075
# Iter 27, rows added: 5.4, rows reducted: 0.6, current samp. ratio: 0.2225
# Iter 28, rows added: 3.6, rows reducted: 2.4, current samp. ratio: 0.22625
# Iter 29, rows added: 4.4, rows reducted: 0.6, current samp. ratio: 0.238125
# Iter 30, rows added: 1.6, rows reducted: 2.8, current samp. ratio: 0.234375
#
# return at Iter ind:  30
# samp. ratio: 0.234375, loss of returned mask: (0.08638237267732621, 0.6464188098907471)
#
# alpha_ind 9 out of 9
# loss of the input mask:  (0.11267460584640503, 0.7367446422576904)
# Iter 2, rows added: 0.0, rows reducted: 56.6, current samp. ratio: 0.073125
# Iter 3, rows added: 2.2, rows reducted: 3.6, current samp. ratio: 0.06875
# Iter 4, rows added: 2.2, rows reducted: 1.4, current samp. ratio: 0.07125
# Iter 5, rows added: 1.4, rows reducted: 1.2, current samp. ratio: 0.071875
# Iter 6, rows added: 2.6, rows reducted: 0.2, current samp. ratio: 0.079375
# Iter 7, rows added: 2.0, rows reducted: 1.0, current samp. ratio: 0.0825
# Iter 8, rows added: 4.0, rows reducted: 0.8, current samp. ratio: 0.0925
# Iter 9, rows added: 2.8, rows reducted: 1.6, current samp. ratio: 0.09625
# Iter 10, rows added: 5.2, rows reducted: 0.6, current samp. ratio: 0.110625
# Iter 11, rows added: 2.0, rows reducted: 2.8, current samp. ratio: 0.108125
# Iter 12, rows added: 3.2, rows reducted: 3.2, current samp. ratio: 0.108125
# Iter 13, rows added: 3.6, rows reducted: 1.6, current samp. ratio: 0.114375
# Iter 14, rows added: 4.2, rows reducted: 0.2, current samp. ratio: 0.126875
# Iter 15, rows added: 3.4, rows reducted: 3.0, current samp. ratio: 0.128125
# Iter 16, rows added: 4.2, rows reducted: 0.0, current samp. ratio: 0.14125
# Iter 17, rows added: 1.6, rows reducted: 2.8, current samp. ratio: 0.1375
# Iter 18, rows added: 5.4, rows reducted: 1.2, current samp. ratio: 0.150625
# Iter 19, rows added: 2.4, rows reducted: 0.4, current samp. ratio: 0.156875
# Iter 20, rows added: 1.8, rows reducted: 4.0, current samp. ratio: 0.15
# Iter 21, rows added: 6.4, rows reducted: 1.6, current samp. ratio: 0.165
# Iter 22, rows added: 2.4, rows reducted: 0.8, current samp. ratio: 0.17
# Iter 23, rows added: 2.4, rows reducted: 0.8, current samp. ratio: 0.175
# Iter 24, rows added: 1.6, rows reducted: 0.6, current samp. ratio: 0.178125
# Iter 25, rows added: 1.6, rows reducted: 1.0, current samp. ratio: 0.18
# Iter 26, rows added: 2.0, rows reducted: 0.4, current samp. ratio: 0.185
# Iter 27, rows added: 1.4, rows reducted: 2.8, current samp. ratio: 0.180625
# Iter 28, rows added: 3.0, rows reducted: 1.2, current samp. ratio: 0.18625
# Iter 29, rows added: 2.4, rows reducted: 1.8, current samp. ratio: 0.188125
# Iter 30, rows added: 2.0, rows reducted: 0.8, current samp. ratio: 0.191875
#
# return at Iter ind:  30
# samp. ratio: 0.19187500000000002, loss of returned mask: (0.0924470990896225, 0.6937050461769104)
#
#
#
# c_ind 2 out of 4
# alpha_ind 1 out of 9
# loss of the input mask:  (0.11267462819814682, 0.7367447972297668)
# Iter 2, rows added: 0.0, rows reducted: 31.0, current samp. ratio: 0.153125
# Iter 3, rows added: 3.4, rows reducted: 3.6, current samp. ratio: 0.1525
# Iter 4, rows added: 19.4, rows reducted: 5.0, current samp. ratio: 0.1975
# Iter 5, rows added: 7.6, rows reducted: 6.8, current samp. ratio: 0.2
# Iter 6, rows added: 11.2, rows reducted: 6.2, current samp. ratio: 0.215625
# Iter 7, rows added: 10.6, rows reducted: 6.0, current samp. ratio: 0.23
# Iter 8, rows added: 4.4, rows reducted: 8.2, current samp. ratio: 0.218125
# Iter 9, rows added: 9.4, rows reducted: 1.0, current samp. ratio: 0.244375
# Iter 10, rows added: 8.4, rows reducted: 10.6, current samp. ratio: 0.2375
# Iter 11, rows added: 11.6, rows reducted: 2.6, current samp. ratio: 0.265625
# Iter 12, rows added: 9.8, rows reducted: 1.6, current samp. ratio: 0.29125
# Iter 13, rows added: 7.0, rows reducted: 9.4, current samp. ratio: 0.28375
# Iter 14, rows added: 9.2, rows reducted: 3.0, current samp. ratio: 0.303125
# Iter 15, rows added: 5.4, rows reducted: 3.0, current samp. ratio: 0.310625
# Iter 16, rows added: 6.2, rows reducted: 2.2, current samp. ratio: 0.323125
# Iter 17, rows added: 8.6, rows reducted: 2.4, current samp. ratio: 0.3425
# Iter 18, rows added: 6.6, rows reducted: 0.6, current samp. ratio: 0.36125
# Iter 19, rows added: 5.8, rows reducted: 4.2, current samp. ratio: 0.36625
# Iter 20, rows added: 6.8, rows reducted: 0.8, current samp. ratio: 0.385
# Iter 21, rows added: 7.2, rows reducted: 2.6, current samp. ratio: 0.399375
# Iter 22, rows added: 8.6, rows reducted: 0.2, current samp. ratio: 0.425625
# Iter 23, rows added: 5.8, rows reducted: 2.0, current samp. ratio: 0.4375
# Iter 24, rows added: 5.4, rows reducted: 0.6, current samp. ratio: 0.4525
# Iter 25, rows added: 7.2, rows reducted: 1.4, current samp. ratio: 0.470625
# Iter 26, rows added: 4.6, rows reducted: 1.6, current samp. ratio: 0.48
# Iter 27, rows added: 5.8, rows reducted: 2.2, current samp. ratio: 0.49125
# Iter 28, rows added: 4.6, rows reducted: 2.4, current samp. ratio: 0.498125
# Iter 29, rows added: 6.4, rows reducted: 2.8, current samp. ratio: 0.509375
# Iter 30, rows added: 7.0, rows reducted: 1.2, current samp. ratio: 0.5275
#
# return at Iter ind:  30
# samp. ratio: 0.5275, loss of returned mask: (0.053418849408626554, 0.30824241042137146)
#
# alpha_ind 2 out of 9
# loss of the input mask:  (0.1126745417714119, 0.7367442369461059)
# Iter 2, rows added: 0.0, rows reducted: 34.0, current samp. ratio: 0.14375
# Iter 3, rows added: 4.2, rows reducted: 3.4, current samp. ratio: 0.14625
# Iter 4, rows added: 17.8, rows reducted: 6.2, current samp. ratio: 0.1825
# Iter 5, rows added: 6.6, rows reducted: 8.8, current samp. ratio: 0.175625
# Iter 6, rows added: 10.4, rows reducted: 4.0, current samp. ratio: 0.195625
# Iter 7, rows added: 7.4, rows reducted: 3.0, current samp. ratio: 0.209375
# Iter 8, rows added: 9.6, rows reducted: 2.0, current samp. ratio: 0.233125
# Iter 9, rows added: 3.8, rows reducted: 6.6, current samp. ratio: 0.224375
# Iter 10, rows added: 12.2, rows reducted: 2.6, current samp. ratio: 0.254375
# Iter 11, rows added: 6.0, rows reducted: 5.6, current samp. ratio: 0.255625
# Iter 12, rows added: 7.8, rows reducted: 1.8, current samp. ratio: 0.274375
# Iter 13, rows added: 7.2, rows reducted: 1.2, current samp. ratio: 0.293125
# Iter 14, rows added: 3.8, rows reducted: 2.8, current samp. ratio: 0.29625
# Iter 15, rows added: 4.6, rows reducted: 0.4, current samp. ratio: 0.309375
# Iter 16, rows added: 6.2, rows reducted: 2.2, current samp. ratio: 0.321875
# Iter 17, rows added: 4.2, rows reducted: 1.2, current samp. ratio: 0.33125
# Iter 18, rows added: 7.4, rows reducted: 1.6, current samp. ratio: 0.349375
# Iter 19, rows added: 4.4, rows reducted: 0.8, current samp. ratio: 0.360625
# Iter 20, rows added: 4.2, rows reducted: 0.2, current samp. ratio: 0.373125
# Iter 21, rows added: 2.6, rows reducted: 0.4, current samp. ratio: 0.38
# Iter 22, rows added: 6.0, rows reducted: 1.0, current samp. ratio: 0.395625
# Iter 23, rows added: 6.8, rows reducted: 1.6, current samp. ratio: 0.411875
# Iter 24, rows added: 6.2, rows reducted: 1.6, current samp. ratio: 0.42625
# Iter 25, rows added: 3.8, rows reducted: 0.6, current samp. ratio: 0.43625
# Iter 26, rows added: 5.6, rows reducted: 0.6, current samp. ratio: 0.451875
# Iter 27, rows added: 4.4, rows reducted: 0.4, current samp. ratio: 0.464375
# Iter 28, rows added: 6.0, rows reducted: 1.6, current samp. ratio: 0.478125
# Iter 29, rows added: 5.0, rows reducted: 0.8, current samp. ratio: 0.49125
# Iter 30, rows added: 4.8, rows reducted: 2.4, current samp. ratio: 0.49875
#
# return at Iter ind:  30
# samp. ratio: 0.49874999999999997, loss of returned mask: (0.05960086956620216, 0.33910040855407714)
#
# alpha_ind 3 out of 9
# loss of the input mask:  (0.11267457604408264, 0.7367443680763245)
# Iter 2, rows added: 0.0, rows reducted: 36.2, current samp. ratio: 0.136875
# Iter 3, rows added: 3.8, rows reducted: 3.8, current samp. ratio: 0.136875
# Iter 4, rows added: 14.4, rows reducted: 4.6, current samp. ratio: 0.1675
# Iter 5, rows added: 6.4, rows reducted: 8.8, current samp. ratio: 0.16
# Iter 6, rows added: 10.6, rows reducted: 3.0, current samp. ratio: 0.18375
# Iter 7, rows added: 4.8, rows reducted: 4.4, current samp. ratio: 0.185
# Iter 8, rows added: 7.8, rows reducted: 1.4, current samp. ratio: 0.205
# Iter 9, rows added: 4.2, rows reducted: 3.2, current samp. ratio: 0.208125
# Iter 10, rows added: 7.6, rows reducted: 6.8, current samp. ratio: 0.210625
# Iter 11, rows added: 8.2, rows reducted: 0.2, current samp. ratio: 0.235625
# Iter 12, rows added: 5.4, rows reducted: 3.2, current samp. ratio: 0.2425
# Iter 13, rows added: 6.0, rows reducted: 2.8, current samp. ratio: 0.2525
# Iter 14, rows added: 5.6, rows reducted: 2.6, current samp. ratio: 0.261875
# Iter 15, rows added: 4.6, rows reducted: 2.8, current samp. ratio: 0.2675
# Iter 16, rows added: 5.2, rows reducted: 2.0, current samp. ratio: 0.2775
# Iter 17, rows added: 4.8, rows reducted: 2.0, current samp. ratio: 0.28625
# Iter 18, rows added: 5.2, rows reducted: 0.6, current samp. ratio: 0.300625
# Iter 19, rows added: 4.4, rows reducted: 0.6, current samp. ratio: 0.3125
# Iter 20, rows added: 2.8, rows reducted: 2.0, current samp. ratio: 0.315
# Iter 21, rows added: 3.6, rows reducted: 1.4, current samp. ratio: 0.321875
# Iter 22, rows added: 4.2, rows reducted: 0.2, current samp. ratio: 0.334375
# Iter 23, rows added: 5.2, rows reducted: 1.2, current samp. ratio: 0.346875
# Iter 24, rows added: 2.6, rows reducted: 0.6, current samp. ratio: 0.353125
# Iter 25, rows added: 5.2, rows reducted: 0.8, current samp. ratio: 0.366875
# Iter 26, rows added: 6.0, rows reducted: 0.2, current samp. ratio: 0.385
# Iter 27, rows added: 5.0, rows reducted: 0.4, current samp. ratio: 0.399375
# Iter 28, rows added: 3.0, rows reducted: 0.2, current samp. ratio: 0.408125
# Iter 29, rows added: 3.8, rows reducted: 1.4, current samp. ratio: 0.415625
# Iter 30, rows added: 5.2, rows reducted: 0.6, current samp. ratio: 0.43
#
# return at Iter ind:  30
# samp. ratio: 0.43, loss of returned mask: (0.06298723220825195, 0.4108571231365204)
#
# alpha_ind 4 out of 9
# loss of the input mask:  (0.11267456412315369, 0.7367443442344666)
# Iter 2, rows added: 0.0, rows reducted: 38.2, current samp. ratio: 0.130625
# Iter 3, rows added: 3.2, rows reducted: 3.8, current samp. ratio: 0.12875
# Iter 4, rows added: 9.0, rows reducted: 4.2, current samp. ratio: 0.14375
# Iter 5, rows added: 4.2, rows reducted: 4.0, current samp. ratio: 0.144375
# Iter 6, rows added: 9.4, rows reducted: 3.0, current samp. ratio: 0.164375
# Iter 7, rows added: 9.4, rows reducted: 8.8, current samp. ratio: 0.16625
# Iter 8, rows added: 8.0, rows reducted: 3.8, current samp. ratio: 0.179375
# Iter 9, rows added: 5.6, rows reducted: 10.0, current samp. ratio: 0.165625
# Iter 10, rows added: 7.0, rows reducted: 1.8, current samp. ratio: 0.181875
# Iter 11, rows added: 6.4, rows reducted: 1.8, current samp. ratio: 0.19625
# Iter 12, rows added: 7.0, rows reducted: 5.6, current samp. ratio: 0.200625
# Iter 13, rows added: 7.0, rows reducted: 1.8, current samp. ratio: 0.216875
# Iter 14, rows added: 3.6, rows reducted: 2.0, current samp. ratio: 0.221875
# Iter 15, rows added: 4.8, rows reducted: 1.0, current samp. ratio: 0.23375
# Iter 16, rows added: 5.2, rows reducted: 1.2, current samp. ratio: 0.24625
# Iter 17, rows added: 4.2, rows reducted: 0.8, current samp. ratio: 0.256875
# Iter 18, rows added: 2.6, rows reducted: 0.6, current samp. ratio: 0.263125
# Iter 19, rows added: 3.0, rows reducted: 0.6, current samp. ratio: 0.270625
# Iter 20, rows added: 3.2, rows reducted: 1.0, current samp. ratio: 0.2775
# Iter 21, rows added: 4.4, rows reducted: 0.4, current samp. ratio: 0.29
# Iter 22, rows added: 5.0, rows reducted: 0.8, current samp. ratio: 0.303125
# Iter 23, rows added: 2.8, rows reducted: 0.0, current samp. ratio: 0.311875
# Iter 24, rows added: 2.6, rows reducted: 1.2, current samp. ratio: 0.31625
# Iter 25, rows added: 3.0, rows reducted: 0.0, current samp. ratio: 0.325625
# Iter 26, rows added: 4.4, rows reducted: 0.6, current samp. ratio: 0.3375
# Iter 27, rows added: 2.4, rows reducted: 0.0, current samp. ratio: 0.345
# Iter 28, rows added: 4.4, rows reducted: 0.8, current samp. ratio: 0.35625
# Iter 29, rows added: 3.6, rows reducted: 0.2, current samp. ratio: 0.366875
# Iter 30, rows added: 5.2, rows reducted: 1.0, current samp. ratio: 0.38
#
# return at Iter ind:  30
# samp. ratio: 0.38, loss of returned mask: (0.06922052055597305, 0.4764861762523651)
#
# alpha_ind 5 out of 9
# loss of the input mask:  (0.1126745581626892, 0.7367442727088929)
# Iter 2, rows added: 0.0, rows reducted: 40.6, current samp. ratio: 0.123125
# Iter 3, rows added: 2.8, rows reducted: 4.6, current samp. ratio: 0.1175
# Iter 4, rows added: 4.8, rows reducted: 4.0, current samp. ratio: 0.12
# Iter 5, rows added: 4.8, rows reducted: 2.4, current samp. ratio: 0.1275
# Iter 6, rows added: 6.2, rows reducted: 2.4, current samp. ratio: 0.139375
# Iter 7, rows added: 7.4, rows reducted: 4.6, current samp. ratio: 0.148125
# Iter 8, rows added: 7.2, rows reducted: 3.6, current samp. ratio: 0.159375
# Iter 9, rows added: 7.0, rows reducted: 1.2, current samp. ratio: 0.1775
# Iter 10, rows added: 5.2, rows reducted: 6.0, current samp. ratio: 0.175
# Iter 11, rows added: 7.0, rows reducted: 0.4, current samp. ratio: 0.195625
# Iter 12, rows added: 6.2, rows reducted: 0.0, current samp. ratio: 0.215
# Iter 13, rows added: 1.4, rows reducted: 2.8, current samp. ratio: 0.210625
# Iter 14, rows added: 2.2, rows reducted: 3.4, current samp. ratio: 0.206875
# Iter 15, rows added: 4.8, rows reducted: 1.2, current samp. ratio: 0.218125
# Iter 16, rows added: 3.8, rows reducted: 0.8, current samp. ratio: 0.2275
# Iter 17, rows added: 2.6, rows reducted: 0.2, current samp. ratio: 0.235
# Iter 18, rows added: 3.2, rows reducted: 1.2, current samp. ratio: 0.24125
# Iter 19, rows added: 4.0, rows reducted: 0.6, current samp. ratio: 0.251875
# Iter 20, rows added: 2.2, rows reducted: 0.2, current samp. ratio: 0.258125
# Iter 21, rows added: 1.6, rows reducted: 1.8, current samp. ratio: 0.2575
# Iter 22, rows added: 4.0, rows reducted: 0.2, current samp. ratio: 0.269375
# Iter 23, rows added: 3.2, rows reducted: 1.0, current samp. ratio: 0.27625
# Iter 24, rows added: 3.4, rows reducted: 0.0, current samp. ratio: 0.286875
# Iter 25, rows added: 2.6, rows reducted: 1.2, current samp. ratio: 0.29125
# Iter 26, rows added: 3.0, rows reducted: 0.2, current samp. ratio: 0.3
# Iter 27, rows added: 2.6, rows reducted: 0.8, current samp. ratio: 0.305625
# Iter 28, rows added: 2.0, rows reducted: 0.0, current samp. ratio: 0.311875
# Iter 29, rows added: 2.2, rows reducted: 1.4, current samp. ratio: 0.314375
# Iter 30, rows added: 2.2, rows reducted: 1.2, current samp. ratio: 0.3175
# return at Iter ind:  30
# samp. ratio: 0.3175, loss of returned mask: (0.07499695867300034, 0.5498125433921814)
#
# alpha_ind 6 out of 9
# loss of the input mask:  (0.11267454773187638, 0.736744225025177)
# Iter 2, rows added: 0.0, rows reducted: 44.2, current samp. ratio: 0.111875
# Iter 3, rows added: 2.6, rows reducted: 4.8, current samp. ratio: 0.105
# Iter 4, rows added: 5.0, rows reducted: 2.4, current samp. ratio: 0.113125
# Iter 5, rows added: 3.6, rows reducted: 4.6, current samp. ratio: 0.11
# Iter 6, rows added: 5.2, rows reducted: 3.0, current samp. ratio: 0.116875
# Iter 7, rows added: 4.6, rows reducted: 1.0, current samp. ratio: 0.128125
# Iter 8, rows added: 3.6, rows reducted: 4.4, current samp. ratio: 0.125625
# Iter 9, rows added: 6.2, rows reducted: 1.0, current samp. ratio: 0.141875
# Iter 10, rows added: 6.2, rows reducted: 1.6, current samp. ratio: 0.15625
# Iter 11, rows added: 4.2, rows reducted: 2.8, current samp. ratio: 0.160625
# Iter 12, rows added: 6.8, rows reducted: 4.6, current samp. ratio: 0.1675
# Iter 13, rows added: 7.6, rows reducted: 0.6, current samp. ratio: 0.189375
# Iter 14, rows added: 4.0, rows reducted: 4.0, current samp. ratio: 0.189375
# Iter 15, rows added: 6.4, rows reducted: 0.6, current samp. ratio: 0.2075
# Iter 16, rows added: 2.6, rows reducted: 1.8, current samp. ratio: 0.21
# Iter 17, rows added: 2.2, rows reducted: 0.4, current samp. ratio: 0.215625
# Iter 18, rows added: 3.0, rows reducted: 1.2, current samp. ratio: 0.22125
# Iter 19, rows added: 2.8, rows reducted: 0.4, current samp. ratio: 0.22875
# Iter 20, rows added: 3.8, rows reducted: 1.4, current samp. ratio: 0.23625
# Iter 21, rows added: 2.8, rows reducted: 1.6, current samp. ratio: 0.24
# Iter 22, rows added: 4.6, rows reducted: 1.4, current samp. ratio: 0.25
# Iter 23, rows added: 2.4, rows reducted: 1.2, current samp. ratio: 0.25375
# Iter 24, rows added: 3.0, rows reducted: 1.0, current samp. ratio: 0.26
# Iter 25, rows added: 1.8, rows reducted: 2.4, current samp. ratio: 0.258125
# Iter 26, rows added: 3.8, rows reducted: 1.4, current samp. ratio: 0.265625
# Iter 27, rows added: 4.6, rows reducted: 1.4, current samp. ratio: 0.275625
# Iter 28, rows added: 3.4, rows reducted: 1.0, current samp. ratio: 0.283125
# Iter 29, rows added: 3.6, rows reducted: 1.8, current samp. ratio: 0.28875
# Iter 30, rows added: 4.4, rows reducted: 1.8, current samp. ratio: 0.296875
#
# return at Iter ind:  30
# samp. ratio: 0.296875, loss of returned mask: (0.08002940118312836, 0.5753578662872314)
#
# alpha_ind 7 out of 9
# loss of the input mask:  (0.11267461329698562, 0.7367447137832641)
# Iter 2, rows added: 0.0, rows reducted: 48.2, current samp. ratio: 0.099375
# Iter 3, rows added: 1.6, rows reducted: 2.8, current samp. ratio: 0.095625
# Iter 4, rows added: 3.8, rows reducted: 4.4, current samp. ratio: 0.09375
# Iter 5, rows added: 3.8, rows reducted: 3.0, current samp. ratio: 0.09625
# Iter 6, rows added: 3.4, rows reducted: 1.2, current samp. ratio: 0.103125
# Iter 7, rows added: 2.4, rows reducted: 2.6, current samp. ratio: 0.1025
# Iter 8, rows added: 6.8, rows reducted: 2.0, current samp. ratio: 0.1175
# Iter 9, rows added: 5.2, rows reducted: 2.8, current samp. ratio: 0.125
# Iter 10, rows added: 5.2, rows reducted: 2.8, current samp. ratio: 0.1325
# Iter 11, rows added: 4.2, rows reducted: 3.8, current samp. ratio: 0.13375
# Iter 12, rows added: 9.8, rows reducted: 0.4, current samp. ratio: 0.163125
# Iter 13, rows added: 3.4, rows reducted: 3.0, current samp. ratio: 0.164375
# Iter 14, rows added: 4.4, rows reducted: 1.6, current samp. ratio: 0.173125
# Iter 15, rows added: 4.2, rows reducted: 1.2, current samp. ratio: 0.1825
# Iter 16, rows added: 3.2, rows reducted: 1.6, current samp. ratio: 0.1875
# Iter 17, rows added: 3.2, rows reducted: 3.8, current samp. ratio: 0.185625
# Iter 18, rows added: 5.6, rows reducted: 4.2, current samp. ratio: 0.19
# Iter 19, rows added: 5.6, rows reducted: 0.6, current samp. ratio: 0.205625
# Iter 20, rows added: 3.0, rows reducted: 1.2, current samp. ratio: 0.21125
# Iter 21, rows added: 1.8, rows reducted: 2.4, current samp. ratio: 0.209375
# Iter 22, rows added: 3.4, rows reducted: 0.4, current samp. ratio: 0.21875
# Iter 23, rows added: 1.8, rows reducted: 2.2, current samp. ratio: 0.2175
# Iter 24, rows added: 3.6, rows reducted: 0.6, current samp. ratio: 0.226875
# Iter 25, rows added: 4.4, rows reducted: 1.6, current samp. ratio: 0.235625
# Iter 26, rows added: 3.2, rows reducted: 1.2, current samp. ratio: 0.241875
# Iter 27, rows added: 2.2, rows reducted: 1.0, current samp. ratio: 0.245625
# Iter 28, rows added: 3.6, rows reducted: 1.0, current samp. ratio: 0.25375
# Iter 29, rows added: 2.2, rows reducted: 2.4, current samp. ratio: 0.253125
# Iter 30, rows added: 4.0, rows reducted: 1.2, current samp. ratio: 0.261875
#
# return at Iter ind:  30
# samp. ratio: 0.261875, loss of returned mask: (0.08271447867155075, 0.6166143655776978)
#
# alpha_ind 8 out of 9
# loss of the input mask:  (0.11267460435628891, 0.7367446780204773)
# Iter 2, rows added: 0.0, rows reducted: 50.8, current samp. ratio: 0.09125
# Iter 3, rows added: 1.6, rows reducted: 4.6, current samp. ratio: 0.081875
# Iter 4, rows added: 3.8, rows reducted: 2.2, current samp. ratio: 0.086875
# Iter 5, rows added: 1.6, rows reducted: 2.0, current samp. ratio: 0.085625
# Iter 6, rows added: 2.4, rows reducted: 2.6, current samp. ratio: 0.085
# Iter 7, rows added: 2.2, rows reducted: 1.4, current samp. ratio: 0.0875
# Iter 8, rows added: 4.4, rows reducted: 1.4, current samp. ratio: 0.096875
# Iter 9, rows added: 2.2, rows reducted: 1.4, current samp. ratio: 0.099375
# Iter 10, rows added: 6.6, rows reducted: 2.0, current samp. ratio: 0.11375
# Iter 11, rows added: 3.4, rows reducted: 1.6, current samp. ratio: 0.119375
# Iter 12, rows added: 5.6, rows reducted: 3.8, current samp. ratio: 0.125
# Iter 13, rows added: 4.4, rows reducted: 1.4, current samp. ratio: 0.134375
# Iter 14, rows added: 5.4, rows reducted: 3.6, current samp. ratio: 0.14
# Iter 15, rows added: 7.4, rows reducted: 0.4, current samp. ratio: 0.161875
# Iter 16, rows added: 4.0, rows reducted: 5.6, current samp. ratio: 0.156875
# Iter 17, rows added: 7.2, rows reducted: 0.0, current samp. ratio: 0.179375
# Iter 18, rows added: 1.8, rows reducted: 4.0, current samp. ratio: 0.1725
# Iter 19, rows added: 5.4, rows reducted: 0.2, current samp. ratio: 0.18875
# Iter 20, rows added: 2.4, rows reducted: 2.6, current samp. ratio: 0.188125
# Iter 21, rows added: 3.8, rows reducted: 1.4, current samp. ratio: 0.195625
# Iter 22, rows added: 3.0, rows reducted: 1.8, current samp. ratio: 0.199375
# Iter 23, rows added: 1.8, rows reducted: 2.6, current samp. ratio: 0.196875
# Iter 24, rows added: 3.4, rows reducted: 1.6, current samp. ratio: 0.2025
# Iter 25, rows added: 2.4, rows reducted: 1.6, current samp. ratio: 0.205
# Iter 26, rows added: 3.0, rows reducted: 0.6, current samp. ratio: 0.2125
# Iter 27, rows added: 1.2, rows reducted: 2.2, current samp. ratio: 0.209375
# Iter 28, rows added: 4.0, rows reducted: 2.2, current samp. ratio: 0.215
# Iter 29, rows added: 4.0, rows reducted: 1.6, current samp. ratio: 0.2225
# Iter 30, rows added: 2.8, rows reducted: 5.0, current samp. ratio: 0.215625
#
# return at Iter ind:  30
# samp. ratio: 0.215625, loss of returned mask: (0.09087554663419724, 0.6618025422096252)
#
# alpha_ind 9 out of 9
# loss of the input mask:  (0.11267454028129578, 0.7367441654205322)
# Iter 2, rows added: 0.0, rows reducted: 55.8, current samp. ratio: 0.075625
# Iter 3, rows added: 2.2, rows reducted: 3.4, current samp. ratio: 0.071875
# Iter 4, rows added: 0.8, rows reducted: 2.2, current samp. ratio: 0.0675
# Iter 5, rows added: 2.6, rows reducted: 0.4, current samp. ratio: 0.074375
# Iter 6, rows added: 2.6, rows reducted: 1.4, current samp. ratio: 0.078125
# Iter 7, rows added: 2.6, rows reducted: 1.6, current samp. ratio: 0.08125
# Iter 8, rows added: 4.0, rows reducted: 2.4, current samp. ratio: 0.08625
# Iter 9, rows added: 3.4, rows reducted: 0.6, current samp. ratio: 0.095
# Iter 10, rows added: 4.2, rows reducted: 1.2, current samp. ratio: 0.104375
# Iter 11, rows added: 3.0, rows reducted: 0.8, current samp. ratio: 0.11125
# Iter 12, rows added: 3.4, rows reducted: 2.8, current samp. ratio: 0.113125
# Iter 13, rows added: 4.8, rows reducted: 1.0, current samp. ratio: 0.125
# Iter 14, rows added: 2.8, rows reducted: 1.4, current samp. ratio: 0.129375
# Iter 15, rows added: 3.6, rows reducted: 2.0, current samp. ratio: 0.134375
# Iter 16, rows added: 5.8, rows reducted: 4.6, current samp. ratio: 0.138125
# Iter 17, rows added: 6.6, rows reducted: 0.2, current samp. ratio: 0.158125
# Iter 18, rows added: 3.2, rows reducted: 3.4, current samp. ratio: 0.1575
# Iter 19, rows added: 4.4, rows reducted: 2.0, current samp. ratio: 0.165
# Iter 20, rows added: 4.0, rows reducted: 2.2, current samp. ratio: 0.170625
# Iter 21, rows added: 2.6, rows reducted: 2.6, current samp. ratio: 0.170625
# Iter 22, rows added: 3.4, rows reducted: 3.8, current samp. ratio: 0.169375
# Iter 23, rows added: 4.4, rows reducted: 2.4, current samp. ratio: 0.175625
# Iter 24, rows added: 4.4, rows reducted: 3.8, current samp. ratio: 0.1775
# Iter 25, rows added: 5.8, rows reducted: 2.2, current samp. ratio: 0.18875
# Iter 26, rows added: 2.6, rows reducted: 2.6, current samp. ratio: 0.18875
# Iter 27, rows added: 4.6, rows reducted: 2.0, current samp. ratio: 0.196875
# Iter 28, rows added: 2.4, rows reducted: 5.2, current samp. ratio: 0.188125
# Iter 29, rows added: 6.0, rows reducted: 2.6, current samp. ratio: 0.19875
# Iter 30, rows added: 3.0, rows reducted: 3.6, current samp. ratio: 0.196875
#
# return at Iter ind:  30
# samp. ratio: 0.19687500000000002, loss of returned mask: (0.09248261302709579, 0.6848854184150696)
#
#
#
# c_ind 3 out of 4
# alpha_ind 1 out of 9
# loss of the input mask:  (0.11267455667257309, 0.7367442965507507)
# Iter 4, rows added: 2.4, rows reducted: 0.0, current samp. ratio: 0.2575
# Iter 5, rows added: 0.6, rows reducted: 0.0, current samp. ratio: 0.259375
# Iter 6, rows added: 2.2, rows reducted: 0.0, current samp. ratio: 0.26625
# Iter 7, rows added: 2.6, rows reducted: 0.6, current samp. ratio: 0.2725
# Iter 8, rows added: 6.2, rows reducted: 2.0, current samp. ratio: 0.285625
# Iter 9, rows added: 6.0, rows reducted: 0.8, current samp. ratio: 0.301875
# Iter 10, rows added: 6.0, rows reducted: 0.8, current samp. ratio: 0.318125
# Iter 11, rows added: 3.0, rows reducted: 2.2, current samp. ratio: 0.320625
# Iter 12, rows added: 5.2, rows reducted: 2.4, current samp. ratio: 0.329375
# Iter 13, rows added: 3.6, rows reducted: 2.4, current samp. ratio: 0.333125
# Iter 14, rows added: 5.2, rows reducted: 2.0, current samp. ratio: 0.343125
# Iter 15, rows added: 4.0, rows reducted: 1.2, current samp. ratio: 0.351875
# Iter 16, rows added: 1.8, rows reducted: 0.6, current samp. ratio: 0.355625
# Iter 17, rows added: 3.4, rows reducted: 3.4, current samp. ratio: 0.355625
# Iter 18, rows added: 4.0, rows reducted: 0.0, current samp. ratio: 0.368125
# Iter 19, rows added: 1.2, rows reducted: 1.4, current samp. ratio: 0.3675
# Iter 20, rows added: 2.0, rows reducted: 3.2, current samp. ratio: 0.36375
# Iter 21, rows added: 3.6, rows reducted: 5.8, current samp. ratio: 0.356875
# Iter 22, rows added: 10.0, rows reducted: 0.2, current samp. ratio: 0.3875
# Iter 23, rows added: 3.6, rows reducted: 0.8, current samp. ratio: 0.39625
# Iter 24, rows added: 1.8, rows reducted: 1.2, current samp. ratio: 0.398125
# Iter 25, rows added: 2.4, rows reducted: 0.0, current samp. ratio: 0.405625
# Iter 26, rows added: 2.6, rows reducted: 1.6, current samp. ratio: 0.40875
# Iter 27, rows added: 3.4, rows reducted: 0.0, current samp. ratio: 0.419375
# Iter 28, rows added: 2.8, rows reducted: 2.0, current samp. ratio: 0.421875
# Iter 29, rows added: 4.8, rows reducted: 0.8, current samp. ratio: 0.434375
# Iter 30, rows added: 3.0, rows reducted: 1.8, current samp. ratio: 0.438125
#
# return at Iter ind:  30
# samp. ratio: 0.438125, loss of returned mask: (0.06779883205890655, 0.5075907588005066)
#
# alpha_ind 2 out of 9
# loss of the input mask:  (0.11267456710338593, 0.7367443442344666)
# Iter 4, rows added: 2.4, rows reducted: 0.0, current samp. ratio: 0.2575
# Iter 5, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.258125
# Iter 6, rows added: 2.4, rows reducted: 0.4, current samp. ratio: 0.264375
# Iter 7, rows added: 2.8, rows reducted: 0.8, current samp. ratio: 0.270625
# Iter 8, rows added: 6.4, rows reducted: 1.2, current samp. ratio: 0.286875
# Iter 9, rows added: 5.2, rows reducted: 1.0, current samp. ratio: 0.3
# Iter 10, rows added: 5.2, rows reducted: 1.6, current samp. ratio: 0.31125
# Iter 11, rows added: 4.8, rows reducted: 2.0, current samp. ratio: 0.32
# Iter 12, rows added: 4.6, rows reducted: 3.4, current samp. ratio: 0.32375
# Iter 13, rows added: 3.6, rows reducted: 3.4, current samp. ratio: 0.324375
# Iter 14, rows added: 5.8, rows reducted: 1.2, current samp. ratio: 0.33875
# Iter 15, rows added: 5.0, rows reducted: 1.2, current samp. ratio: 0.350625
# Iter 16, rows added: 1.8, rows reducted: 1.0, current samp. ratio: 0.353125
# Iter 17, rows added: 3.0, rows reducted: 3.2, current samp. ratio: 0.3525
# Iter 18, rows added: 4.4, rows reducted: 0.2, current samp. ratio: 0.365625
# Iter 19, rows added: 1.0, rows reducted: 3.0, current samp. ratio: 0.359375
# Iter 20, rows added: 4.0, rows reducted: 0.6, current samp. ratio: 0.37
# Iter 21, rows added: 1.6, rows reducted: 0.4, current samp. ratio: 0.37375
# Iter 22, rows added: 1.8, rows reducted: 0.6, current samp. ratio: 0.3775
# Iter 23, rows added: 4.6, rows reducted: 0.6, current samp. ratio: 0.39
# Iter 24, rows added: 2.4, rows reducted: 1.8, current samp. ratio: 0.391875
# Iter 25, rows added: 3.2, rows reducted: 0.4, current samp. ratio: 0.400625
# Iter 26, rows added: 1.4, rows reducted: 0.4, current samp. ratio: 0.40375
# Iter 27, rows added: 2.6, rows reducted: 0.8, current samp. ratio: 0.409375
# Iter 28, rows added: 4.0, rows reducted: 1.2, current samp. ratio: 0.418125
# Iter 29, rows added: 3.4, rows reducted: 2.8, current samp. ratio: 0.42
# Iter 30, rows added: 6.0, rows reducted: 1.6, current samp. ratio: 0.43375
#
# return at Iter ind:  30
# samp. ratio: 0.43374999999999997, loss of returned mask: (0.06766587197780609, 0.512724655866623)
#
# alpha_ind 3 out of 9
# loss of the input mask:  (0.11267458200454712, 0.736744499206543)
# Iter 4, rows added: 2.2, rows reducted: 0.4, current samp. ratio: 0.255625
# Iter 5, rows added: 0.8, rows reducted: 0.6, current samp. ratio: 0.25625
# Iter 6, rows added: 2.4, rows reducted: 0.2, current samp. ratio: 0.263125
# Iter 7, rows added: 1.6, rows reducted: 0.2, current samp. ratio: 0.2675
# ...
# Iter 23, rows added: 6.0, rows reducted: 1.8, current samp. ratio: 0.165
# Iter 24, rows added: 3.0, rows reducted: 5.2, current samp. ratio: 0.158125
# Iter 25, rows added: 7.2, rows reducted: 0.8, current samp. ratio: 0.178125
# Iter 26, rows added: 2.0, rows reducted: 4.0, current samp. ratio: 0.171875
# Iter 27, rows added: 5.0, rows reducted: 2.2, current samp. ratio: 0.180625
# Iter 28, rows added: 2.6, rows reducted: 5.0, current samp. ratio: 0.173125
# Iter 29, rows added: 5.2, rows reducted: 0.6, current samp. ratio: 0.1875
# Iter 30, rows added: 1.4, rows reducted: 5.2, current samp. ratio: 0.175625
#
# return at Iter ind:  30
# samp. ratio: 0.17562499999999998, loss of returned mask: (0.09558554142713546, 0.6993831753730774)
#
#
#
# c_ind 4 out of 4
# alpha_ind 1 out of 9
# loss of the input mask:  (0.1126745507121086, 0.736744225025177)
# Iter 9, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 12, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.251875
# Iter 13, rows added: 0.6, rows reducted: 0.2, current samp. ratio: 0.253125
# Iter 14, rows added: 0.6, rows reducted: 0.0, current samp. ratio: 0.255
# Iter 15, rows added: 0.6, rows reducted: 0.4, current samp. ratio: 0.255625
# Iter 16, rows added: 1.2, rows reducted: 1.2, current samp. ratio: 0.255625
# Iter 17, rows added: 1.4, rows reducted: 0.4, current samp. ratio: 0.25875
# Iter 18, rows added: 0.8, rows reducted: 0.2, current samp. ratio: 0.260625
# Iter 19, rows added: 1.0, rows reducted: 1.6, current samp. ratio: 0.25875
# Iter 20, rows added: 2.6, rows reducted: 1.8, current samp. ratio: 0.26125
# Iter 21, rows added: 2.2, rows reducted: 0.8, current samp. ratio: 0.265625
# Iter 22, rows added: 1.4, rows reducted: 3.0, current samp. ratio: 0.260625
# Iter 23, rows added: 2.8, rows reducted: 1.2, current samp. ratio: 0.265625
# Iter 24, rows added: 2.6, rows reducted: 3.2, current samp. ratio: 0.26375
# Iter 25, rows added: 4.2, rows reducted: 1.2, current samp. ratio: 0.273125
# Iter 26, rows added: 2.6, rows reducted: 4.2, current samp. ratio: 0.268125
# Iter 27, rows added: 4.4, rows reducted: 2.6, current samp. ratio: 0.27375
# Iter 28, rows added: 3.6, rows reducted: 3.4, current samp. ratio: 0.274375
# Iter 29, rows added: 3.0, rows reducted: 3.6, current samp. ratio: 0.2725
# Iter 30, rows added: 5.0, rows reducted: 4.2, current samp. ratio: 0.275
#
# return at Iter ind:  30
# samp. ratio: 0.275, loss of returned mask: (0.1004370018839836, 0.701851737499237)
#
# alpha_ind 2 out of 9
# loss of the input mask:  (0.11267455965280533, 0.7367442965507507)
# Iter 9, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 12, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.251875
# Iter 13, rows added: 0.6, rows reducted: 0.2, current samp. ratio: 0.253125
# Iter 14, rows added: 0.4, rows reducted: 0.2, current samp. ratio: 0.25375
# Iter 15, rows added: 0.8, rows reducted: 0.2, current samp. ratio: 0.255625
# Iter 16, rows added: 1.2, rows reducted: 0.4, current samp. ratio: 0.258125
# Iter 17, rows added: 0.8, rows reducted: 1.0, current samp. ratio: 0.2575
# Iter 18, rows added: 1.6, rows reducted: 1.0, current samp. ratio: 0.259375
# Iter 19, rows added: 1.4, rows reducted: 1.2, current samp. ratio: 0.26
# Iter 20, rows added: 2.2, rows reducted: 2.0, current samp. ratio: 0.260625
# Iter 21, rows added: 2.0, rows reducted: 0.6, current samp. ratio: 0.265
# Iter 22, rows added: 1.4, rows reducted: 2.4, current samp. ratio: 0.261875
# Iter 23, rows added: 2.6, rows reducted: 1.2, current samp. ratio: 0.26625
# Iter 24, rows added: 2.0, rows reducted: 3.0, current samp. ratio: 0.263125
# Iter 25, rows added: 4.2, rows reducted: 1.2, current samp. ratio: 0.2725
# Iter 26, rows added: 2.4, rows reducted: 4.4, current samp. ratio: 0.26625
# Iter 27, rows added: 5.2, rows reducted: 2.0, current samp. ratio: 0.27625
# Iter 28, rows added: 2.2, rows reducted: 4.4, current samp. ratio: 0.269375
# Iter 29, rows added: 4.0, rows reducted: 2.8, current samp. ratio: 0.273125
# Iter 30, rows added: 4.8, rows reducted: 5.0, current samp. ratio: 0.2725
#
# return at Iter ind:  30
# samp. ratio: 0.2725, loss of returned mask: (0.10239863693714142, 0.7048226237297058)
#
# alpha_ind 3 out of 9
# loss of the input mask:  (0.11267457902431488, 0.736744487285614)
# Iter 9, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 12, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.251875
# Iter 13, rows added: 0.4, rows reducted: 0.2, current samp. ratio: 0.2525
# Iter 14, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25375
# Iter 15, rows added: 1.0, rows reducted: 0.8, current samp. ratio: 0.254375
# Iter 16, rows added: 1.4, rows reducted: 0.4, current samp. ratio: 0.2575
# Iter 17, rows added: 0.8, rows reducted: 0.8, current samp. ratio: 0.2575
# Iter 18, rows added: 1.2, rows reducted: 1.0, current samp. ratio: 0.258125
# Iter 19, rows added: 2.0, rows reducted: 1.0, current samp. ratio: 0.26125
# Iter 20, rows added: 1.6, rows reducted: 1.8, current samp. ratio: 0.260625
# Iter 21, rows added: 1.8, rows reducted: 0.6, current samp. ratio: 0.264375
# Iter 22, rows added: 1.4, rows reducted: 3.4, current samp. ratio: 0.258125
# Iter 23, rows added: 4.2, rows reducted: 1.0, current samp. ratio: 0.268125
# Iter 24, rows added: 1.4, rows reducted: 2.8, current samp. ratio: 0.26375
# Iter 25, rows added: 3.6, rows reducted: 0.8, current samp. ratio: 0.2725
# Iter 26, rows added: 2.0, rows reducted: 5.4, current samp. ratio: 0.261875
# Iter 27, rows added: 6.0, rows reducted: 0.8, current samp. ratio: 0.278125
# Iter 28, rows added: 2.0, rows reducted: 6.4, current samp. ratio: 0.264375
# Iter 29, rows added: 6.0, rows reducted: 2.2, current samp. ratio: 0.27625
# Iter 30, rows added: 3.6, rows reducted: 4.0, current samp. ratio: 0.275
#
# return at Iter ind:  30
# samp. ratio: 0.275, loss of returned mask: (0.10036925822496415, 0.7012007474899292)
#
# alpha_ind 4 out of 9
# loss of the input mask:  (0.11267463266849517, 0.7367448449134827)
# Iter 9, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 12, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.251875
# Iter 13, rows added: 0.4, rows reducted: 0.2, current samp. ratio: 0.2525
# Iter 14, rows added: 0.4, rows reducted: 0.2, current samp. ratio: 0.253125
# Iter 15, rows added: 1.2, rows reducted: 0.4, current samp. ratio: 0.255625
# Iter 16, rows added: 0.8, rows reducted: 0.4, current samp. ratio: 0.256875
# Iter 17, rows added: 0.8, rows reducted: 1.0, current samp. ratio: 0.25625
# Iter 18, rows added: 1.4, rows reducted: 1.0, current samp. ratio: 0.2575
# Iter 19, rows added: 2.0, rows reducted: 0.8, current samp. ratio: 0.26125
# Iter 20, rows added: 1.2, rows reducted: 2.2, current samp. ratio: 0.258125
# Iter 21, rows added: 2.4, rows reducted: 0.6, current samp. ratio: 0.26375
# Iter 22, rows added: 1.6, rows reducted: 2.0, current samp. ratio: 0.2625
# Iter 23, rows added: 2.4, rows reducted: 2.0, current samp. ratio: 0.26375
# Iter 24, rows added: 2.4, rows reducted: 2.4, current samp. ratio: 0.26375
# Iter 25, rows added: 2.8, rows reducted: 1.4, current samp. ratio: 0.268125
# Iter 26, rows added: 3.4, rows reducted: 3.8, current samp. ratio: 0.266875
# Iter 27, rows added: 4.6, rows reducted: 2.4, current samp. ratio: 0.27375
# Iter 28, rows added: 3.2, rows reducted: 4.4, current samp. ratio: 0.27
# Iter 29, rows added: 4.0, rows reducted: 3.6, current samp. ratio: 0.27125
# Iter 30, rows added: 4.4, rows reducted: 3.6, current samp. ratio: 0.27375
#
# return at Iter ind:  30
# samp. ratio: 0.27375, loss of returned mask: (0.10042367428541184, 0.7009509325027465)
#
# alpha_ind 5 out of 9
# loss of the input mask:  (0.1126745581626892, 0.7367443203926086)
# Iter 9, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 12, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.251875
# Iter 13, rows added: 0.4, rows reducted: 0.2, current samp. ratio: 0.2525
# Iter 14, rows added: 0.2, rows reducted: 0.4, current samp. ratio: 0.251875
# Iter 15, rows added: 1.2, rows reducted: 0.4, current samp. ratio: 0.254375
# Iter 16, rows added: 0.6, rows reducted: 0.2, current samp. ratio: 0.255625
# Iter 17, rows added: 1.2, rows reducted: 0.2, current samp. ratio: 0.25875
# Iter 18, rows added: 0.8, rows reducted: 0.2, current samp. ratio: 0.260625
# Iter 19, rows added: 0.6, rows reducted: 1.2, current samp. ratio: 0.25875
# Iter 20, rows added: 1.8, rows reducted: 1.6, current samp. ratio: 0.259375
# Iter 21, rows added: 2.0, rows reducted: 1.2, current samp. ratio: 0.261875
# Iter 22, rows added: 2.0, rows reducted: 2.6, current samp. ratio: 0.26
# Iter 23, rows added: 2.6, rows reducted: 1.2, current samp. ratio: 0.264375
# Iter 24, rows added: 2.0, rows reducted: 2.0, current samp. ratio: 0.264375
# Iter 25, rows added: 2.6, rows reducted: 2.0, current samp. ratio: 0.26625
# Iter 26, rows added: 3.2, rows reducted: 3.0, current samp. ratio: 0.266875
# Iter 27, rows added: 3.6, rows reducted: 1.6, current samp. ratio: 0.273125
# Iter 28, rows added: 3.0, rows reducted: 4.2, current samp. ratio: 0.269375
# Iter 29, rows added: 4.2, rows reducted: 3.2, current samp. ratio: 0.2725
# Iter 30, rows added: 4.2, rows reducted: 3.4, current samp. ratio: 0.275
#
# return at Iter ind:  30
# samp. ratio: 0.275, loss of returned mask: (0.10010891854763031, 0.6989424824714661)
#
# alpha_ind 6 out of 9
# loss of the input mask:  (0.11267460435628891, 0.7367446303367615)
# Iter 9, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 12, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.251875
# Iter 13, rows added: 0.4, rows reducted: 0.2, current samp. ratio: 0.2525
# Iter 14, rows added: 0.0, rows reducted: 0.4, current samp. ratio: 0.25125
# Iter 15, rows added: 1.2, rows reducted: 0.4, current samp. ratio: 0.25375
# Iter 16, rows added: 1.2, rows reducted: 0.2, current samp. ratio: 0.256875
# Iter 17, rows added: 1.0, rows reducted: 0.4, current samp. ratio: 0.25875
# Iter 18, rows added: 0.8, rows reducted: 1.6, current samp. ratio: 0.25625
# Iter 19, rows added: 1.4, rows reducted: 1.0, current samp. ratio: 0.2575
# Iter 20, rows added: 2.2, rows reducted: 0.8, current samp. ratio: 0.261875
# Iter 21, rows added: 1.0, rows reducted: 1.8, current samp. ratio: 0.259375
# Iter 22, rows added: 2.6, rows reducted: 1.8, current samp. ratio: 0.261875
# Iter 23, rows added: 2.0, rows reducted: 1.2, current samp. ratio: 0.264375
# Iter 24, rows added: 2.0, rows reducted: 2.6, current samp. ratio: 0.2625
# Iter 25, rows added: 2.8, rows reducted: 1.6, current samp. ratio: 0.26625
# Iter 26, rows added: 2.2, rows reducted: 4.4, current samp. ratio: 0.259375
# Iter 27, rows added: 5.6, rows reducted: 0.8, current samp. ratio: 0.274375
# Iter 28, rows added: 1.8, rows reducted: 3.4, current samp. ratio: 0.269375
# Iter 29, rows added: 3.2, rows reducted: 3.2, current samp. ratio: 0.269375
# Iter 30, rows added: 4.2, rows reducted: 4.0, current samp. ratio: 0.27
#
# return at Iter ind:  30
# samp. ratio: 0.27, loss of returned mask: (0.10280257910490036, 0.7063560843467712)
#
# alpha_ind 7 out of 9
# loss of the input mask:  (0.11267460137605667, 0.7367446184158325)
# Iter 9, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 12, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.251875
# Iter 13, rows added: 0.4, rows reducted: 0.2, current samp. ratio: 0.2525
# Iter 14, rows added: 0.0, rows reducted: 0.6, current samp. ratio: 0.250625
# Iter 15, rows added: 1.4, rows reducted: 0.0, current samp. ratio: 0.255
# Iter 16, rows added: 0.6, rows reducted: 0.4, current samp. ratio: 0.255625
# Iter 17, rows added: 0.6, rows reducted: 0.6, current samp. ratio: 0.255625
# Iter 18, rows added: 1.4, rows reducted: 1.2, current samp. ratio: 0.25625
# Iter 19, rows added: 1.6, rows reducted: 0.4, current samp. ratio: 0.26
# Iter 20, rows added: 1.0, rows reducted: 1.4, current samp. ratio: 0.25875
# Iter 21, rows added: 1.8, rows reducted: 1.0, current samp. ratio: 0.26125
# Iter 22, rows added: 1.6, rows reducted: 2.4, current samp. ratio: 0.25875
# Iter 23, rows added: 2.8, rows reducted: 1.2, current samp. ratio: 0.26375
# Iter 24, rows added: 1.6, rows reducted: 2.6, current samp. ratio: 0.260625
# Iter 25, rows added: 2.8, rows reducted: 1.0, current samp. ratio: 0.26625
# Iter 26, rows added: 1.8, rows reducted: 3.6, current samp. ratio: 0.260625
# Iter 27, rows added: 3.6, rows reducted: 1.2, current samp. ratio: 0.268125
# Iter 28, rows added: 3.2, rows reducted: 3.4, current samp. ratio: 0.2675
# Iter 29, rows added: 4.2, rows reducted: 3.2, current samp. ratio: 0.270625
# Iter 30, rows added: 3.8, rows reducted: 4.2, current samp. ratio: 0.269375
#
# return at Iter ind:  30
# samp. ratio: 0.269375, loss of returned mask: (0.10254908949136735, 0.7062363266944885)
#
# alpha_ind 8 out of 9
# loss of the input mask:  (0.11267462223768235, 0.73674476146698)
# Iter 9, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.250625
# Iter 10, rows added: 0.2, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 13, rows added: 0.4, rows reducted: 0.4, current samp. ratio: 0.25125
# Iter 14, rows added: 0.4, rows reducted: 0.4, current samp. ratio: 0.25125
# Iter 15, rows added: 1.0, rows reducted: 0.4, current samp. ratio: 0.253125
# Iter 16, rows added: 1.2, rows reducted: 0.6, current samp. ratio: 0.255
# Iter 17, rows added: 0.8, rows reducted: 0.2, current samp. ratio: 0.256875
# Iter 18, rows added: 1.0, rows reducted: 0.8, current samp. ratio: 0.2575
# Iter 19, rows added: 0.6, rows reducted: 1.4, current samp. ratio: 0.255
# Iter 20, rows added: 1.8, rows reducted: 1.2, current samp. ratio: 0.256875
# Iter 21, rows added: 2.2, rows reducted: 0.2, current samp. ratio: 0.263125
# Iter 22, rows added: 0.8, rows reducted: 2.4, current samp. ratio: 0.258125
# Iter 23, rows added: 2.2, rows reducted: 1.0, current samp. ratio: 0.261875
# Iter 24, rows added: 2.0, rows reducted: 3.0, current samp. ratio: 0.25875
# Iter 25, rows added: 3.0, rows reducted: 0.6, current samp. ratio: 0.26625
# Iter 26, rows added: 1.4, rows reducted: 3.2, current samp. ratio: 0.260625
# Iter 27, rows added: 3.2, rows reducted: 1.6, current samp. ratio: 0.265625
# Iter 28, rows added: 2.4, rows reducted: 3.0, current samp. ratio: 0.26375
# Iter 29, rows added: 4.6, rows reducted: 1.6, current samp. ratio: 0.273125
# Iter 30, rows added: 2.0, rows reducted: 5.2, current samp. ratio: 0.263125
#
# return at Iter ind:  30
# samp. ratio: 0.263125, loss of returned mask: (0.10517380237579346, 0.7139093041419983)
#
# alpha_ind 9 out of 9
# loss of the input mask:  (0.11267457455396652, 0.7367443680763245)
# Iter 11, rows added: 0.4, rows reducted: 0.0, current samp. ratio: 0.25125
# Iter 13, rows added: 0.0, rows reducted: 0.4, current samp. ratio: 0.25
# Iter 14, rows added: 0.8, rows reducted: 0.0, current samp. ratio: 0.2525
# Iter 15, rows added: 0.0, rows reducted: 0.8, current samp. ratio: 0.25
# Iter 16, rows added: 1.8, rows reducted: 0.0, current samp. ratio: 0.255625
# Iter 17, rows added: 0.4, rows reducted: 0.2, current samp. ratio: 0.25625
# Iter 18, rows added: 0.4, rows reducted: 1.4, current samp. ratio: 0.253125
# Iter 19, rows added: 1.4, rows reducted: 0.4, current samp. ratio: 0.25625
# Iter 20, rows added: 1.2, rows reducted: 1.4, current samp. ratio: 0.255625
# Iter 21, rows added: 1.8, rows reducted: 0.6, current samp. ratio: 0.259375
# Iter 22, rows added: 1.8, rows reducted: 1.8, current samp. ratio: 0.259375
# Iter 23, rows added: 2.2, rows reducted: 1.4, current samp. ratio: 0.261875
# Iter 24, rows added: 1.8, rows reducted: 2.2, current samp. ratio: 0.260625
# Iter 25, rows added: 2.0, rows reducted: 1.2, current samp. ratio: 0.263125
# Iter 26, rows added: 1.6, rows reducted: 3.0, current samp. ratio: 0.25875
# Iter 27, rows added: 3.0, rows reducted: 1.0, current samp. ratio: 0.265
# Iter 28, rows added: 2.0, rows reducted: 3.6, current samp. ratio: 0.26
# Iter 29, rows added: 3.6, rows reducted: 1.8, current samp. ratio: 0.265625
# Iter 30, rows added: 2.8, rows reducted: 2.8, current samp. ratio: 0.265625
#
# return at Iter ind:  30
# samp. ratio: 0.265625, loss of returned mask: (0.10426786094903946, 0.7118300437927246)

# %%
# highmask = sigmoid_binarize(raw_normalize(mnet(z),budget=budget))
randmask = torch.zeros(highmask.shape)
for ind in range(highmask.shape[0]):
    sampinds = np.random.choice(highmask.shape[1],budget,replace=False)
    randmask[ind,sampinds] = 1
lowfmask,_,_ = mask_naiveRand(xstar.shape[1]-corefreq,fix=budget,other=0,roll=True)
lowfmask = lowfmask.repeat(highmask.shape[0],1)

# %%
# full_highmask = mask_complete(highmask,320)
full_randmask = mask_complete(randmask,320)
full_lowfmask = mask_complete(lowfmask,320)

(rand_l2,rand_hfen) = mask_eval(full_randmask,xstar,mode='sigpy',hfen=True)
(lowf_l2,lowf_hfen) = mask_eval(full_lowfmask,xstar,mode='sigpy',hfen=True)
# (gred_l2,gred_hfen) = mask_eval(full_gredmask.to(torch.float),xstar,mode='sigpy',hfen=True)
print('mode = sigpy')

print(rand_l2)
print(lowf_l2)
# print(gred_l2)
# Out:
# mode = sigpy
# 0.11985646039247513
# 0.08402363061904908

# %%
# mnet_loss = mask_eval(full_highmask,xstar,mode='UNET',UNET=UNET)
# rand_loss = mask_eval(full_randmask,xstar,mode='UNET',UNET=UNET)
# lowf_loss = mask_eval(full_lowfmask,xstar,mode='UNET',UNET=UNET)
# print('mode = UNet')
# mnet_loss = mask_eval(full_highmask,xstar,mode='sigpy')
(rand_l2,rand_hfen) = mask_eval(full_randmask,xstar,mode='sigpy',hfen=True)
(lowf_l2,lowf_hfen) = mask_eval(full_lowfmask,xstar,mode='sigpy',hfen=True)
(gred_l2,gred_hfen) = mask_eval(full_gredmask.to(torch.float),xstar,mode='sigpy',hfen=True)
print('mode = sigpy')
# print(mnet_loss)

print(rand_l2)
print(lowf_l2)
print(gred_l2)

# %%
plt.figure()
plt.plot(alpha_grid,l2loss)
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*rand_l2,label='rand')
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*lowf_l2,label='low freq.')
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*gred_l2,label='greedy')
plt.title('l2 loss of masks')
plt.xscale('log')
plt.legend(loc='best')

plt.figure()
plt.plot(alpha_grid,hfen)
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*rand_hfen,label='rand')
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*lowf_hfen,label='low freq.')
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*gred_hfen,label='greedy')
plt.title('HFEN of masks')
plt.xscale('log')
plt.legend(loc='best')

plt.figure()
plt.plot(alpha_grid,sparsity,label='actual')
plt.plot(alpha_grid,(corefreq+budget)/320*np.ones(alpha_grid.shape),label='target')
plt.title('mask sparsity')
plt.xscale('log')
plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7bf2f91a4754> in <module>
#       3 plt.plot(alpha_grid,np.ones(alpha_grid.shape)*rand_l2,label='rand')
#       4 plt.plot(alpha_grid,np.ones(alpha_grid.shape)*lowf_l2,label='low freq.')
# ----> 5 plt.plot(alpha_grid,np.ones(alpha_grid.shape)*gred_l2,label='greedy')
#       6 plt.title('l2 loss of masks')
#       7 plt.xscale('log')
#
# NameError: name 'gred_l2' is not defined

# %%
markers = ['H', 'D', 'P', 'X','+']
plt.figure(figsize=(10,8))
for c_ind in range(len(c_grid)):
    plt.plot(alpha_grid,l2loss[:,c_ind],label='c='+str(c_grid[c_ind]),marker=markers[c_ind],markersize=7)
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*rand_l2,color='r',label='rand')
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*lowf_l2,color='g',label='low freq.')
# plt.plot(alpha_grid,np.ones(alpha_grid.shape)*gred_l2,color='k',label='greedy')
plt.title('l2 loss of masks')
plt.xlabel('alpha')
plt.xscale('log')
plt.legend(loc='best',bbox_to_anchor=(1.05, 1))

plt.figure(figsize=(10,8))
for c_ind in range(len(c_grid)):
    plt.plot(alpha_grid,hfen[:,c_ind],label='c='+str(c_grid[c_ind]),marker=markers[c_ind],markersize=7)
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*rand_hfen,color='r',label='rand')
plt.plot(alpha_grid,np.ones(alpha_grid.shape)*lowf_hfen,color='g',label='low freq.')
# plt.plot(alpha_grid,np.ones(alpha_grid.shape)*gred_hfen,color='k',label='greedy')
plt.title('HFEN of masks')
plt.xscale('log')
plt.legend(loc='best')

plt.figure(figsize=(10,8))
for c_ind in range(len(c_grid)):
    plt.plot(alpha_grid,sparsity[:,c_ind],label='c='+str(c_grid[c_ind]),marker=markers[c_ind],markersize=7)
plt.plot(alpha_grid,(corefreq+budget)/320*np.ones(alpha_grid.shape),'-.',label='target')
plt.title('mask sparsity')
plt.xscale('log')
plt.legend(loc='best')
plt.xlabel('alpha')
# Out:
# Text(0.5, 0, 'alpha')

# %%
np.log10(alpha_grid[-5])

# %%
from sigpy.mri.app import TotalVariationRecon
xstar = imgs[0,:,:]/torch.max(torch.abs(imgs[0,:,:].flatten()))
imgHeg, imgWid = xstar.shape[0], xstar.shape[1]
mps = np.ones((1,imgHeg,imgWid))
imgind = 15

NN = 15
Lambda_grid = 10**(np.linspace(-4,-2.5,NN))
errors = np.zeros((NN))

y = torch.fft.fftshift(F.fftn(xstar,dim=(0,1),norm='ortho'),dim=(0,1))    
z = torch.zeros(y.shape).to(y.dtype)
z[masks[imgind,:]==1,:] = y[masks[imgind,:]==1,:]  
y_tmp = z.view(-1,imgHeg,imgWid).numpy()

xstar = xstar.numpy()

ind = 0
for Lambda in Lambda_grid:    
    x_tmp = np.fft.ifftshift( np.abs(TotalVariationRecon(y_tmp, mps, Lambda, show_pbar=False).run()) )  
    errors[ind] = np.linalg.norm(x_tmp - xstar,'fro')/np.linalg.norm(xstar,'fro')
    ind += 1
    
plt.figure()
plt.plot(Lambda_grid,errors)
plt.xscale('log')
plt.show()

# %% [markdown]
# ### tune weight initialization function

# %%
def mnet_weights_init(m):
    classname = m.__class__.__name__
    print(m)
    if classname.find('Conv2d') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# reload(utils)
# from utils import mnet_weights_init

# %%
corefreq = 8
budget = 32

mnet = MNet(beta=1,in_channels=2,out_size=320-corefreq, imgsize=(320,320),poolk=3)
# mnet.apply(mnet_weights_init)
# mnet.eval()
mnet(torch.randn(1,2,320,320))

# %% [markdown]
# ### old tests

# %%
from mask_backward_v3 import ThresholdBinarizeMask

# %%
binarize = ThresholdBinarizeMask.apply
x = torch.tensor([0.5,-0.5],requires_grad=True)

# %%
y = binarize(torch.sigmoid(3*x))
ystar = torch.tensor([0.,1.])
print(y)

# %%
loss = 1/2*torch.norm(y - ystar,p=2)
optimizer = optim.SGD([{'params': x}], lr=1e-2, momentum=0)
optimizer.zero_grad()
loss.backward()

# %%
x.grad

# %%
data_gt = np.load('/home/huangz78/data/data_gt.npz')
picind = np.random.randint(199)
xstar = data_gt['imgdata'][:,:,27]
xstar = xstar/np.max(np.abs(xstar))
# highmask = datafornn['labels'][picind,:]
plt.figure()
plt.imshow(xstar)
plt.colorbar()
plt.show()

# %%
# reload(maskbackward)
# from maskbackward import mask_backward

#mode UNET:

reload(mask_backward_new)
from mask_backward_new import mask_backward,mask_eval

dtyp = torch.float
# unroll_block = 8; Lambda=6.1e-4; rho=1e1

# base = .05; expand = .15
# highmask = torch.zeros((round(320*(1-base))),dtype=torch.double)
# highmask[np.random.choice(round(320*(1-base)),round(320*expand),replace=False)] = 1

highmask = mask_filter(fullmask,base=round(320*0.05),roll=True)
print(highmask.shape)

# %%
n_channels = 1
UNET =  UNet(n_channels=n_channels,n_classes=n_channels,bilinear=True,skip=False)
checkpoint = torch.load('/home/huangz78/checkpoints/unet_' + str(n_channels) + '.pth')
UNET.load_state_dict(checkpoint['model_state_dict'])
UNET.eval()

# %%
## quick comparison between ifft recon and unet recon
imgHeg = 320; imgWid = 320
fullmask = torch.tensor( mask_complete(highmask,imgHeg,dtyp=torch.float) )
kplot(fullmask)
print('sparsity of fullmask = ',fullmask.sum().item()/imgHeg)

# %%
xstar = torch.tensor(xstar,dtype=dtyp)
DTyp = torch.cfloat if dtyp==torch.float else torch.cdouble
y = torch.fft.fftshift(F.fftn(xstar,dim=(0,1),norm='ortho'))
z = torch.fft.ifftshift(torch.tensordot(torch.diag(fullmask).to(DTyp),y,dims=([1],[0])))
kplot(y,roll=False,log=True)
kplot(z,roll=True,log=True)

# %%
imgHeg = 320; imgWid = 320
x_ifft = torch.abs(F.ifftn(z,dim=(0,1),norm='ortho')).to(dtyp)
x_unet = UNET(x_ifft.view(1,1,imgHeg,imgWid)).detach()

print('error of x_ifft = ', torch.norm(torch.flatten(x_ifft)-torch.flatten(xstar),'fro')/torch.norm(xstar,'fro') )
print('error of x_unet = ', torch.norm(torch.flatten(x_unet)-torch.flatten(xstar),'fro')/torch.norm(xstar,'fro') )

# %%
from sigpy.mri.app import TotalVariationRecon
NN = 50
Lambda_grid = 10**np.linspace(-3.5,-3,NN)
errRec = np.zeros((NN))
ind = 1

mps  = np.ones((1,imgHeg,imgWid))
y_sp = np.reshape(z.numpy(),(-1,imgHeg,imgWid))
for Lambda in Lambda_grid:
# Lambda = 10**(-6.31) 
# Lambda = 10**(-3.2755) # np.log10(Lambda_grid[np.argmin(errRec)])
    print('{} out of {}'.format(ind,NN))
    x_sp = np.fft.fftshift( np.abs(TotalVariationRecon(y_sp, mps, Lambda,show_pbar=False).run()) ) 
    x_sp = torch.tensor(x_sp)
    errRec[ind-1] = torch.norm(torch.flatten(x_sp)-torch.flatten(xstar),'fro')/torch.norm(xstar,'fro')
    ind += 1
#     print('error of x_sp = ', torch.norm(torch.flatten(x_sp)-torch.flatten(xstar),'fro')/torch.norm(xstar,'fro'))

plt.figure()
plt.xscale('log')
plt.plot(Lambda_grid,errRec)

# %%
np.linspace(-6,-4,gridnum)[8]

# %%
reload(mask_backward_new)
from mask_backward_new import mask_backward,mask_eval

maxIter = 200
gridnum = 10
alpha_grid = 10**np.linspace(-4.6,-4.5,gridnum)
sr_rec = np.zeros((gridnum))
mloss_rec = np.zeros(gridnum)

ind = 0
for alpha in alpha_grid:
    print('[{}/{}]  alpha {}'.format(ind+1,gridnum,alpha))
    highmask_refined,refine_mloss,init_loss = mask_backward(highmask,xstar,\
                          beta=1., alpha=alpha,maxIter=maxIter,seed=0,break_limit=maxIter//2,\
                          lr=5e-4,mode='UNET',\
                          verbose=False,dtyp=dtyp)
    print('Difference between masks: \n',highmask_refined - highmask)
#     print('Refined mask is: \n',highmask_refined)
    mloss_rec[ind] = refine_mloss
    sr_rec[ind] = (torch.sum(highmask_refined).item() + 24)/320
    ind += 1

# %%
plt.figure()
plt.scatter(alpha_grid,mloss_rec,label='refined')
plt.scatter(alpha_grid,init_loss*np.ones(mloss_rec.shape),label='init.')
plt.title('mask loss')
plt.xscale('log')
plt.legend(loc='best')
plt.show()

plt.figure()
plt.scatter(alpha_grid,sr_rec,label='refined')
plt.scatter(alpha_grid,0.25*np.ones(mloss_rec.shape),label='init.')
plt.title('mask sampling ratio')
plt.xscale('log')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### mask binarize test

# %%
from torch.autograd import Function
class ThresholdBinarizeMask(Function):
    def __init__(self):
        """
            Straight through estimator.
            The forward step binarizes the real-valued mask.
            The backward step estimate the non differentiable > operator using sigmoid with large slope (10).
        """
        super(ThresholdBinarizeMask, self).__init__()

    @staticmethod
    def forward(ctx, input):
        batch_size = len(input)
        results = [] 

        for i in range(batch_size):
            x = input[i:i+1]
            result = (x > .5).float()
            results.append(result)

        results = torch.cat(results, dim=0)
#         ctx.save_for_backward(input)
        return results  

    @staticmethod
    def backward(ctx, grad_output):
        slope = 1
#         input = ctx.saved_tensors

        # derivative of M
        current_grad = slope

        return current_grad * grad_output

# %%
threshold = ThresholdBinarizeMask.apply

# %%
x = torch.tensor([.1,.3,.7,.9,.6,.5,.21,.43])
x.requires_grad = True
b = threshold(x)

# %%
y = torch.tensor([1., 1., 1., 1., 0., 1., 0., 1.])
loss = torch.norm((y-b),p=2)**2

# %%
optimizer = optim.SGD([{'params': x}], lr=1e-2)

# %%
optimizer.zero_grad()
loss.backward()
print('old x: ', x)
print('grad: ', x.grad)
optimizer.step()
print('updated x: ', x)

# %% [markdown]
# ### arXiv

# %%
reload(mask_backward_new)
from mask_backward_new import mask_backward

# mode ADMM:

highmask = torch.zeros((round(320*0.9)))
highmask[np.random.choice(round(320*0.9),int(320*.1),replace=False)] = 1

naive_mloss = mask_eval(mask_complete(highmask.to(torch.double),320),xstar,unroll_block=unroll_block,Lambda=Lambda,rho=rho) * 100
highmask_refined,refine_mloss = mask_backward(highmask,xstar,\
                          beta=1., alpha=1e1,maxIter=200,unroll_block=unroll_block,seed=0,break_limit=100,\
                          lr=5e-4,mode='ADMM',Lambda=Lambda,rho=rho,\
                          verbose=True,perturb=False,perturb_freq=5,eps=1e-2)

# %%
# vary sampling ratio, observe RMSE for the same image.
reload(mask_backward_new)
from mask_backward_new import mask_backward

base=0.1
r_grid = np.array([0.1,0.15,0.2])
naive_mloss = np.zeros((r_grid.size))
refine_mloss = np.zeros((r_grid.size))

sampRatio = np.zeros((r_grid.size))

unroll_block = 6; Lambda=6.1e-4; rho=1e1; lr = 5e-2
maxIter = 300; break_limit = round(maxIter/3)

np.random.seed(0)

ind = 0
for r in r_grid:
    print('\n r {}, the {} item out of {}'.format(r,ind+1,r_grid.size))
    highmask = torch.zeros((round(320*(1-base))))
    highmask[np.random.choice(round(320*(1-base)),int(320*r),replace=False)] = 1
    
    naive_mloss[ind] = mask_eval(mask_complete(highmask.to(torch.double),320),xstar,unroll_block=unroll_block,Lambda=Lambda,rho=rho) * 100
    highmask_refined,refine_mloss[ind] = mask_backward(highmask,xstar,seed=0,\
                              beta=1., alpha=9.5e0,maxIter=maxIter,unroll_block=unroll_block,break_limit=break_limit,\
                              lr=lr,mode='ADMM',Lambda=Lambda,rho=rho,\
                              verbose=True,perturb=False,perturb_freq=5,eps=1e-2)
    sampRatio[ind] = (highmask_refined.sum().item() + round(320*0.1))/320
    ind += 1

# %%
print('sampRatio: ',sampRatio)
plt.figure()
plt.scatter(r_grid,naive_mloss,label='naive')
plt.scatter(sampRatio,refine_mloss,label='refined')
plt.legend(bbox_to_anchor=(1.04,0.5), loc="center left")

# %%
## find a good alpha for l1 penalty
reload(mask_backward_new); reload(utils);
from mask_backward_new import mask_backward
alpha_grid = np.linspace(1,10,10)
sparsity_ = np.zeros(alpha_grid.size)
change_count = np.zeros(alpha_grid.size)

unroll_block = 6; Lambda=6.1e-4; rho=1e1; lr = 5e-2
maxIter = 300; break_limit = round(maxIter/2)
# add samp. ratio. = .1 ---> best alpha = ?
# add samp. ratio. = .2 ---> best alpha = ?
# add samp. ratio. = .2 ---> best alpha = ?

base = 0.05
additional = 0.125

highmask = torch.zeros((round(320*(1-base))))
highmask[np.random.choice(round(320*(1-base)),round(320*additional),replace=False)] = 1

ind = 0
for alpha in alpha_grid:
    print('\n\talpha = {}'.format(alpha))
    highmask_refined,_ = mask_backward(highmask,xstar,\
                  beta=1, alpha=alpha,maxIter=maxIter,unroll_block=unroll_block,seed=0,break_limit=break_limit,\
                  lr=lr,mode='ADMM',Lambda=Lambda,rho=rho,\
                  perturb=False,perturb_freq=10,verbose=True)
    sparsity_[ind] = mask_complete(highmask_refined.to(torch.double),320).sum().item()/320
    change_count[ind] = torch.abs(highmask_refined - highmask).sum().item()
    ind += 1

# %%
plt.figure()
plt.scatter(alpha_grid,sparsity_,label='end')
plt.scatter(alpha_grid,(base+additional)*np.ones(alpha_grid.size),label='start')
plt.title('sparsity')
# plt.xscale('log')
plt.legend(bbox_to_anchor=(1.04,0.5), loc="center left")

plt.figure()
plt.scatter(alpha_grid,change_count)
# plt.xscale('log')
plt.title('change count')

# %%
naive_mloss = mask_eval(mask_complete(highmask,imgHeg,dtyp=dtyp),xstar,mode='UNET',UNET=UNET,dtyp=dtyp) * 100
print('naive mask loss = ',naive_mloss)

# %%
### verify that UNET works fine
z = apply_mask(full_gredmask,yfull,mode='c')
xs = torch.abs(F.ifftn(F.ifftshift(z),dim=(1,2),norm='ortho'))
xs = torch.reshape(xs,(xs.shape[0],1,xs.shape[1],xs.shape[2]))

UNET.eval()
imgind = 0
xrecon = UNET(xs)
plt.figure()
plt.title('recon')
plt.imshow(xrecon.detach().numpy()[imgind,0,:,:])
plt.colorbar()
plt.show()

plt.figure()
plt.title('gt')
plt.imshow(xstar.detach().numpy()[imgind,:,:])
plt.colorbar()
plt.show()
print(torch.norm(xrecon[imgind,0,:,:]-xstar[imgind,:,:],'fro')/torch.norm(xstar[imgind,:,:],'fro').item())

# %%
reload(utils)
from utils import hfen

# %%
torch.squeeze(xrecon)[0,:,:].shape

# %%
hfen(torch.squeeze(xrecon)[imgind,:,:],xstar[imgind,:,:],base=0)
