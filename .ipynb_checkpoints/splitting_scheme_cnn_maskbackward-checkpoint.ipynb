# %%
import numpy as np
import argparse
import os
import sys
import torch
import torch.fft as F
from importlib import reload
from torch.nn.functional import relu
import torch.nn as nn
import torch.nn.functional as Func
import torch.optim as optim
import utils
from matplotlib import pyplot as plt
import random
import copy

from utils import kplot,mask_naiveRand,mask_filter, get_x_f_from_yfull
from mnet import MNet

from mask_backward_new import mask_backward, mask_eval
from utils import mask_complete, mask_makebinary,kplot, mask_filter, mask_makebinary,raw_normalize, visualization

sys.path.insert(0,'/home/huangz78/mri/unet/')
from unet_model import UNet

torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %%
# load a mnet
mnet = MNet(out_size=320-24)
checkpoint = torch.load('/home/huangz78/checkpoints/mnet.pth')
mnet.load_state_dict(checkpoint['model_state_dict'])
print('MNet loaded successfully from: ' + '/home/huangz78/checkpoints/mnet.pth')
# Out:
# MNet loaded successfully from: /home/huangz78/checkpoints/mnet.pth

# %%
# load a unet for maskbackward
UNET =  UNet(n_channels=1,n_classes=1,bilinear=True,skip=False)
checkpoint = torch.load('/home/huangz78/checkpoints/unet_'+ str(UNET.n_channels) +'.pth')
UNET.load_state_dict(checkpoint['model_state_dict'])
print('Unet loaded successfully from : ' + '/home/huangz78/checkpoints/unet_'+ str(UNET.n_channels) +'.pth' )
# Out:
# Unet loaded successfully from : /home/huangz78/checkpoints/unet_1.pth

# %%
train_dir = '/home/huangz78/data/traindata_x.npz'
# train_sub = np.load(train_dir)['x']
train_full = np.load(train_dir)['xfull']

# %%
fullmask = torch.fft.fftshift(torch.tensor(np.load(train_dir)['mask'])) # roll the input mask

# %%
test_dir = '/home/huangz78/data/testdata_x.npz'
testimg  = torch.tensor(np.load(test_dir)['x']) 
print(testimg.shape)
# test_sub  = test_sub[0:10,:,:]
# test_full = torch.tensor(np.load(test_dir)['xfull']) 
mask_greedy = np.load('/home/huangz78/data/data_gt_greedymask.npz')
mask_greedy = mask_greedy['mask'].T # this greedy mask is rolled
print(mask_greedy.shape)
# Out:
# torch.Size([199, 320, 320])
# (199, 320)

# %%
# select an image whose greedy mask we have
# test_dir  = '/home/huangz78/data/data_gt.npz'
# test_full = torch.tensor( np.transpose(np.load(test_dir)['imgdata'],axes=(2,0,1)) )

# %%
from utils import visualization
def alternating_update_with_unetRecon(mnet,unet,trainfulls,testimg,mask_init,mask_init_full=True,\
                                      maxIter_mb=50,evalmode='unet',alpha=2.8*1e-5,c=0.05,\
                                      lr_mb=1e-4,lr_mn=1e-4,maxRep=5,\
                                      corefreq=24,budget=24,plot=False,verbose=False,mask_greedy=None,\
                                      change_initmask=True,validate_every=10,dtyp=torch.float):
    '''
    alpha: magnitude of l1 penalty for high-frequency mask
    mnet : the input mnet needs to coordinate exactly with corefreq
    '''
    if mask_init_full:
        fullmask = torch.tensor(mask_init).clone()
        highmask = mask_filter(fullmask,base=corefreq,roll=True)
    else:
        fullmask = mask_complete(torch.tensor(mask_init),trainfulls.shape[1],rolled=True,dtyp=dtyp)
        highmask = torch.tensor(mask_init).clone()
    DTyp = torch.cfloat if dtyp==torch.float else torch.cdouble
    criterion_mnet = nn.BCEWithLogitsLoss()
    
    optimizer_m = optim.RMSprop(mnet.parameters(), lr=lr_mn, weight_decay=0, momentum=0)
    # optimizer_u = ......
    
    unet_eval = UNet(n_channels=1,n_classes=1,bilinear=True,skip=False)
    unet_eval = copy.deepcopy(unet)
    unet_eval.eval()
    # training loop
    global_step = 0

    randqual = []; mnetqual = []
    randspar = []; mnetspar = []
    if mask_greedy is not None:
        greedyqual = []
        greedyspar = np.sum(mask_greedy[0,:])/trainfulls.shape[1]
    else:
        greedyqual = None; greedyspar = None
    
    for xstar in trainfulls:
        xstar = torch.tensor(xstar,dtype=dtyp)
        yfull = torch.fft.fftshift(F.fftn(xstar,dim=(0,1),norm='ortho')) # y is ROLLED!
        lowfreqmask,_,_ = mask_naiveRand(xstar.shape[0],fix=corefreq,other=0,roll=True)
        x_lf            = get_x_f_from_yfull(lowfreqmask,yfull)
        ########################################  
        ## (1) mask_backward
        ########################################        
        if change_initmask and global_step>0: # option 2: highmask = mask_pred from step (2)
            highmask = mnet(x_lf.view(1,1,xstar.shape[0],xstar.shape[1])).view(-1)
        highmask_refined,unet = mask_backward(highmask,xstar,unet=unet, mnet=mnet,\
                          beta=1.,alpha=alpha,c=c,\
                          maxIter=maxIter_mb,seed=0,break_limit=maxIter_mb*3//5,\
                          lr=lr_mb,mode='UNET',budget=budget,normalize=True,\
                          verbose=verbose,dtyp=torch.float)        
        ########################################  
        ## (2) update mnet
        ########################################        
        mnet.train()
        unet.eval()
        rep = 0
        while rep < maxRep:
            mask_pred  = mnet(x_lf.view(1,1,xstar.shape[0],xstar.shape[1]))
#             mask_pred_full = mask_complete(mask_pred.view(-1),xstar.shape[0],rolled=True,dtyp=dtyp) # ??
#             x_lf_new   = get_x_f_from_yfull(mask_pred_full,yfull).view(1,1,xstar.shape[0],xstar.shape[1]) # ??
#             x_unet     = unet(x_lf_new) # ??
            train_loss = criterion_mnet(mask_pred,highmask_refined.view(mask_pred.shape))
            optimizer_m.zero_grad()
            # optimizer step wrt unet parameters ?
            train_loss.backward()
            optimizer_m.step()
            rep += 1
        mnet.eval()             
        ########################################  
        ## (3) check mnet performance: does it beat random sampling?
        ########################################
        if (global_step%validate_every==0) or (global_step==trainfulls.shape[0]-1):
            randqual_tmp = 0; mnetqual_tmp = 0; greedyqual_tmp = 0
            randspar_tmp = 0; mnetspar_tmp = 0
            imgind = 0
            for img in testimg:
#                 img    = torch.tensor(img,dtype=dtyp) # now we test on 1 image only.
#                 yfull_test = torch.fft.fftshift(F.fftn(img,dim=(0,1),norm='ortho'))
#                 x_test_lf  = get_x_f_from_yfull(lowfreqmask,yfull_test)
                x_test_lf     = img
                highmask_tmp  = torch.sigmoid( mnet( x_test_lf.view(1,1,img.shape[0],img.shape[1]) ).view(-1) )   
                highmask_test = mask_makebinary( raw_normalize(highmask_tmp,budget) , sigma=False )
                mask_rand,_,_ = mask_naiveRand(img.shape[0],fix=corefreq,other=highmask_test.sum(),roll=True)
                mask_test     = mask_complete(highmask_test.view(-1),img.shape[0],rolled=True,dtyp=dtyp)

                randqual_img  = mask_eval(mask_rand,img,UNET=unet_eval)
                mnetqual_img  = mask_eval(mask_test,img,UNET=unet_eval) # UNET = unet               
                randqual_tmp += randqual_img
                mnetqual_tmp += mnetqual_img                
                if verbose:
                    print('Quality of random mask : ', randqual_img) # UNET=unet_eval
                    print('Quality of mnet   mask : ', mnetqual_img) # UNET=unet_eval
                    
                ### compute sampling ratio of generated masks
                randspar_img  = mask_rand.sum().item()/img.shape[0]
                mnetspar_img  = mask_test.sum().item()/img.shape[0]
                randspar_tmp += randspar_img
                mnetspar_tmp += mnetspar_img
                if mask_greedy is not None:
                    greedyqual_img = mask_eval(mask_greedy[imgind,:],img,UNET=unet_eval)
                    greedyqual_tmp += greedyqual_img
                    if verbose:
                        print('Quality of greedy mask : ', greedyqual_img)
                        print(f'sparsity of random mask: {randspar_img},mnet mask: {mnetspar_img}, \
                                greedy mask: {greedyspar}\n')
                else:
                    if verbose:
                        print(f'sparsity of random mask: {randspar_img},mnet mask: {mnetspar_img}\n')
                if randspar_img != mnetspar_img:
                    print('breakpoint reached~')
                    breakpoint()
                imgind += 1
            randqual.append( randqual_tmp/testimg.shape[0] )
            mnetqual.append( mnetqual_tmp/testimg.shape[0] )
            if mask_greedy is not None:
                greedyqual.append( greedyqual_tmp/testimg.shape[0] )
            randspar.append( randspar_tmp/testimg.shape[0] )
            mnetspar.append( mnetspar_tmp/testimg.shape[0] )
            
            if plot:
                try:
                    visualization(randqual,mnetqual,greedyqual=greedyqual,\
                             randspar=randspar,mnetspar=mnetspar,greedyspar=greedyspar*np.ones(len(greedyqual)))
                except Exception:
                    visualization(randqual,mnetqual,randspar=randspar,mnetspar=mnetspar)
        global_step += 1
    # return mnet, unet

# %%
alternating_update_with_unetRecon(mnet,UNET,train_full,testimg,fullmask,\
                                  alpha=3e-4,c=1e-2,lr_mb=5e-4,lr_mn=1e-4,\
                                  maxIter_mb=50,maxRep=5,\
                                  corefreq=24,budget=16,\
                                  mask_greedy=mask_greedy,change_initmask=True,\
                                  verbose=False,plot=True,validate_every=50)
# Out:
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if sys.path[0] == '':
# /home/huangz78/mri/mask_backward_new.py:121: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xstar = torch.tensor(xstar,dtype=dtyp); highmask = torch.tensor(highmask,dtype=dtyp)
# /home/huangz78/mri/mask_backward_new.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   fullmask = torch.tensor( mask_complete(M_high,imgHeg,dtyp=dtyp) )
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/autograd/__init__.py:147: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  /opt/conda/conda-bld/pytorch_1616554786529/work/aten/src/ATen/native/Copy.cpp:219.)
#   allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# return at Iter:  50
# loss of returned mask:  10.73470339179039
# return at Iter:  50
# loss of returned mask:  10.296498239040375
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  10.23867279291153
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  10.044583678245544
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.820694476366043
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.737808257341385
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.454168379306793
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.195497632026672
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.25365835428238
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.297637641429901
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.270670264959335
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.826861530542374
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.913260698318481
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.133896976709366
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.799460530281067
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.823762834072113
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.034775197505951
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.16808694601059
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.63613411784172
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.971123397350311
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.708053827285767
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.992092311382294
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.7820403277874
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.888928592205048
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.86257141828537
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.883725851774216
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.980681657791138
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.11284452676773
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.252197206020355
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.325989246368408
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.545042276382446
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.623487949371338
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.924449145793915
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.978142499923706
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.336503505706787
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.200883567333221
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.856800854206085
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.102670013904572
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.954717874526978
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  9.198048710823059
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.43877249956131
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.75167378783226
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  9.48464423418045
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.141824394464493
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.953674882650375
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.905436843633652
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.874361217021942
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.820607513189316
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.765081316232681
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.547962456941605
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  7.723630964756012
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  7.184107601642609
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.540994465351105
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.477130323648453
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.029272943735123
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.100015461444855
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.059474617242813
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.994152396917343
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.042402356863022
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.786217123270035
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.779987692832947
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.992890268564224
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  9.246844798326492
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.529293537139893
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  8.164359629154205
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  12.794466316699982
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.126365840435028
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  14.39104974269867
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.278147578239441
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.285000622272491
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.593529164791107
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.653546571731567
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  13.517364859580994
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  14.090865850448608
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  14.420707523822784
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  14.369086921215057
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  14.925117790699005
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  15.816868841648102
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  11.82141974568367
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  11.65904551744461
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  11.930419504642487
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.117373943328857
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.6437708735466
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  12.58614957332611
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.594173848628998
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.798196077346802
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  12.78226524591446
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.149593770503998
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.774203717708588
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.757444381713867
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.038177788257599
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  8.290989696979523
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  7.979235798120499
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  7.865422964096069
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  7.735966891050339
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  7.425292581319809
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  7.189349830150604
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  6.97193369269371
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  6.858138740062714
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  6.876731663942337
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  6.819827109575272
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  6.661268323659897
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  6.268510967493057
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  5.9466056525707245
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  11.439521610736847
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  11.586962640285492
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  11.879892647266388
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  11.783450841903687
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.470066547393799
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.320252507925034
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.636488676071167
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  12.960682809352875
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  13.281762599945068
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  13.12229186296463
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.957820296287537
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.95015662908554
# No change in row selections after 31 iters, ending iteration~
#
# return at Iter:  30
# loss of returned mask:  12.898100912570953
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  9.860344231128693
# No further decrease in loss after 30 consecutive iters, ending iterations~
#
# return at Iter:  30
# loss of returned mask:  9.852178394794464
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c2d1894449fb> in <module>
#       4                                   corefreq=24,budget=16,\
#       5                                   mask_greedy=mask_greedy,change_initmask=True,\
# ----> 6                                   verbose=False,plot=True,validate_every=50)
#
# <ipython-input-8-9ee996f5fcc6> in alternating_update_with_unetRecon(mnet, unet, trainfulls, testimg, mask_init, mask_init_full, maxIter_mb, evalmode, alpha, c, lr_mb, lr_mn, maxRep, corefreq, budget, plot, verbose, mask_greedy, change_initmask, validate_every, dtyp)
#      49                           maxIter=maxIter_mb,seed=0,break_limit=maxIter_mb*3//5,\
#      50                           lr=lr_mb,mode='UNET',budget=budget,normalize=True,\
# ---> 51                           verbose=verbose,dtyp=torch.float)
#      52         ########################################
#      53         ## (2) update mnet
#
# ~/mri/mask_backward_new.py in mask_backward(highmask, xstar, maxIter, seed, lr, eps, normalize, budget, beta, alpha, c, unet_mode, unet, mnet, unroll_block, Lambda, rho, mode, lr_Lambda, break_limit, print_every, verbose, save_cp, dtyp)
#     186                 x_ifft = torch.abs( F.ifftn(z,dim=(0,1),norm='ortho') ) # undo roll
#     187                 x_in = x_ifft.view(1,1,imgHeg,imgWid).to(dtyp)
# --> 188                 x = UNET(x_in)
#     189         elif mode == 'IFFT': # debug
#     190             x   = torch.abs(F.ifftn(z,dim=(0,1),norm='ortho')) # should involve the mask to cater for the lower-level objective
#
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/mri/unet/unet_model.py in forward(self, x)
#      35         if not self.skip:
#      36             x = self.up1(x5, x4)
# ---> 37             x = self.up2(x, x3)
#      38             x = self.up3(x, x2)
#      39             x = self.up4(x, x1)
#
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/mri/unet/unet_parts.py in forward(self, x1, x2)
#      67         # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
#      68         x = torch.cat([x2, x1], dim=1)
# ---> 69         return self.conv(x)
#      70
#      71
#
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/mri/unet/unet_parts.py in forward(self, x)
#      23
#      24     def forward(self, x):
# ---> 25         return self.double_conv(x)
#      26
#      27
#
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     394                             _pair(0), self.dilation, self.groups)
#     395         return F.conv2d(input, weight, bias, self.stride,
# --> 396                         self.padding, self.dilation, self.groups)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %%
reload(utils)
import mask_backward_new
reload(mask_backward_new)
from mask_backward_new import mask_backward
from utils import raw_normalize, visualization
