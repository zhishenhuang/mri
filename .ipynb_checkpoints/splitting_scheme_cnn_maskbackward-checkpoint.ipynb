# %%
import numpy as np
import argparse
import os
import sys
import torch
import torch.fft as F
from importlib import reload
from torch.nn.functional import relu
import torch.nn as nn
import torch.nn.functional as Func
import torch.optim as optim
import utils
from matplotlib import pyplot as plt
import random
import copy

from utils import kplot,mask_naiveRand,mask_filter, get_x_f_from_yfull
from mnet import MNet

from mask_backward_new import mask_backward, mask_eval
from utils import mask_complete, mask_makebinary,kplot, mask_filter, mask_makebinary,raw_normalize, visualization

sys.path.insert(0,'/home/huangz78/mri/unet/')
from unet_model import UNet

torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %%
# load a mnet
mnet = MNet(out_size=320-24)
checkpoint = torch.load('/home/huangz78/checkpoints/mnet.pth')
mnet.load_state_dict(checkpoint['model_state_dict'])
print('MNet loaded successfully from: ' + '/home/huangz78/checkpoints/mnet.pth')
# Out:
# MNet loaded successfully from: /home/huangz78/checkpoints/mnet.pth

# %%
# load a unet for maskbackward
UNET =  UNet(n_channels=1,n_classes=1,bilinear=True,skip=False)
checkpoint = torch.load('/home/huangz78/checkpoints/unet_'+ str(UNET.n_channels) +'.pth')
UNET.load_state_dict(checkpoint['model_state_dict'])
print('Unet loaded successfully from : ' + '/home/huangz78/checkpoints/unet_'+ str(UNET.n_channels) +'.pth' )
# Out:
# Unet loaded successfully from : /home/huangz78/checkpoints/unet_1.pth

# %%
train_dir = '/home/huangz78/data/traindata_x.npz'
# train_sub = np.load(train_dir)['x']
train_full = np.load(train_dir)['xfull']

# %%
fullmask = torch.fft.fftshift(torch.tensor(np.load(train_dir)['mask'])) # roll the input mask

# %%
test_dir = '/home/huangz78/data/testdata_x.npz'
testimg  = torch.tensor(np.load(test_dir)['x']) 
print(testimg.shape)
# test_sub  = test_sub[0:10,:,:]
# test_full = torch.tensor(np.load(test_dir)['xfull']) 
mask_greedy = np.load('/home/huangz78/data/data_gt_greedymask.npz')
mask_greedy = mask_greedy['mask'].T # this greedy mask is rolled
print(mask_greedy.shape)
# Out:
# torch.Size([199, 320, 320])
# (199, 320)

# %%
# select an image whose greedy mask we have
# test_dir  = '/home/huangz78/data/data_gt.npz'
# test_full = torch.tensor( np.transpose(np.load(test_dir)['imgdata'],axes=(2,0,1)) )

# %%
from utils import visualization
def alternating_update_with_unetRecon(mnet,unet,trainfulls,testimg,mask_init,mask_init_full=True,\
                                      maxIter_mb=50,evalmode='unet',alpha=2.8*1e-5,c=0.05,\
                                      lr_mb=1e-4,lr_mn=1e-4,maxRep=5,\
                                      corefreq=16,budget=48,plot=False,verbose=False,mask_greedy=None,\
                                      change_initmask=True,validate_every=10,dtyp=torch.float):
    '''
    alpha: magnitude of l1 penalty for high-frequency mask
    '''
    if mask_init_full:
        fullmask = torch.tensor(mask_init).clone()
        highmask = mask_filter(fullmask,base=corefreq,roll=True)
    else:
        fullmask = mask_complete(torch.tensor(mask_init),trainfulls.shape[1],rolled=True,dtyp=dtyp)
        highmask = torch.tensor(mask_init).clone()
    DTyp = torch.cfloat if dtyp==torch.float else torch.cdouble
    criterion_mnet = nn.BCEWithLogitsLoss()
    
    optimizer_m = optim.RMSprop(mnet.parameters(), lr=lr_mn, weight_decay=0, momentum=0)
    # optimizer_u = ......
    
    unet_eval = UNet(n_channels=1,n_classes=1,bilinear=True,skip=False)
    unet_eval = copy.deepcopy(unet)
    unet_eval.eval()
    # training loop
    global_step = 0; val_step = 0
    qual_len = int(trainfulls.shape[0]//validate_every) if trainfulls.shape[0]%validate_every==0 else int(trainfulls.shape[0]//validate_every)+1
    randqual = np.zeros((qual_len)); mnetqual = np.zeros((qual_len))
    randspar = np.zeros((qual_len)); mnetspar = np.zeros((qual_len))
    if mask_greedy is not None:
        greedyqual = np.zeros((qual_len))
        greedyspar = np.ones((qual_len)) * np.sum(mask_greedy[0,:])/trainfulls.shape[1]
    else:
        greedyqual = None; greedyspar = None
    
    for xstar in trainfulls:
        xstar = torch.tensor(xstar,dtype=dtyp)
        yfull = torch.fft.fftshift(F.fftn(xstar,dim=(0,1),norm='ortho')) # y is ROLLED!
        lowfreqmask,_,_ = mask_naiveRand(xstar.shape[0],fix=corefreq,other=0,roll=True)
        x_lf            = get_x_f_from_yfull(lowfreqmask,yfull)
        ########################################  
        ## (1) mask_backward
        ########################################        
        if change_initmask and global_step>0: # option 2: highmask = mask_pred from step (2)
            highmask = mnet(x_lf.view(1,1,xstar.shape[0],xstar.shape[1])).view(-1)
        highmask_refined,unet = mask_backward(highmask,xstar,unet=unet, mnet=mnet,\
                          beta=1.,alpha=alpha,c=c,\
                          maxIter=maxIter_mb,seed=0,break_limit=maxIter_mb//2,\
                          lr=lr_mb,mode='UNET',budget=budget,normalize=True,\
                          verbose=verbose,dtyp=torch.float)        
        ########################################  
        ## (2) update mnet
        ########################################        
        mnet.train()
        unet.eval()
        rep = 0
        while rep < maxRep:
            mask_pred  = mnet(x_lf.view(1,1,xstar.shape[0],xstar.shape[1]))
            mask_pred_full = mask_complete(mask_pred.view(-1),xstar.shape[0],rolled=True,dtyp=dtyp)
            x_lf_new   = get_x_f_from_yfull(mask_pred_full,yfull).view(1,1,xstar.shape[0],xstar.shape[1])
            x_unet     = unet(x_lf_new)
            train_loss = criterion_mnet(mask_pred,highmask_refined.view(mask_pred.shape))
            optimizer_m.zero_grad()
            # optimizer step wrt unet parameters ?
            train_loss.backward()
            optimizer_m.step()
            rep += 1
        mnet.eval()             
        ########################################  
        ## (3) check mnet performance: does it beat random sampling?
        ########################################
        if (global_step%validate_every==0) or (global_step==trainfulls.shape[0]-1):
            randqual_tmp = 0; mnetqual_tmp = 0; greedyqual_tmp = 0
            randspar_tmp = 0; mnetspar_tmp = 0
            imgind = 0
            for img in testimg:
#                 img    = torch.tensor(img,dtype=dtyp) # now we test on 1 image only.
#                 yfull_test = torch.fft.fftshift(F.fftn(img,dim=(0,1),norm='ortho'))
#                 x_test_lf  = get_x_f_from_yfull(lowfreqmask,yfull_test)
                x_test_lf     = img
                highmask_tmp  = torch.sigmoid( mnet( x_test_lf.view(1,1,img.shape[0],img.shape[1]) ).view(-1) )   
                highmask_test = mask_makebinary( raw_normalize(highmask_tmp,budget) , sigma=False )

                mask_rand,_,_ = mask_naiveRand(xstar.shape[0],fix=corefreq,other=highmask_test.sum(),roll=True)
                mask_test     = mask_complete(highmask_test.view(-1),xstar.shape[0],rolled=True,dtyp=dtyp)
                
                randqual_img  = mask_eval(mask_rand,img,UNET=unet_eval)
                mnetqual_img  = mask_eval(mask_test,img,UNET=unet_eval)
                
                randqual_tmp += randqual_img
                mnetqual_tmp += mnetqual_img
                
                if verbose:
                    print('Quality of random mask : ', randqual_img) # UNET=unet_eval
                    print('Quality of mnet   mask : ', mnetqual_img) # UNET=unet_eval
                if mask_greedy is not None:
                    greedyqual_img = mask_eval(mask_greedy[imgind,:],img,UNET=unet_eval)
                    if verbose:
                        print('Quality of greedy mask : ', greedyqual_img)
                    greedyqual_tmp += greedyqual_img
                    randspar_tmp += mask_rand.sum().item()/xstar.shape[0]
                    mnetspar_tmp += mask_test.sum().item()/xstar.shape[0]
                    if verbose:
                        print(f'sparsity of random mask: {mask_rand.sum().item()/xstar.shape[0]},\
                                mnet mask: {mask_test.sum().item()/xstar.shape[0]}, \
                                greedy mask: {np.sum(mask_greedy[imgind,:])/xstar.shape[0]}')
                else:
                    randspar_tmp += mask_rand.sum().item()/xstar.shape[0]
                    mnetspar_tmp += mask_test.sum().item()/xstar.shape[0]
                    if verbose:
                        print(f'sparsity of random mask: {mask_rand.sum().item()/xstar.shape[0]},\
                            mnet mask: {mask_test.sum().item()/xstar.shape[0]}')
                if verbose:
                    print('\n')
                imgind += 1
            randqual[val_step] = randqual_tmp/testimg.shape[0]
            mnetqual[val_step] = mnetqual_tmp/testimg.shape[0]
            if mask_greedy is not None:
                greedyqual[val_step] = greedyqual_tmp/testimg.shape[0]
            randspar[val_step] = randspar_tmp/testimg.shape[0]
            mnetspar[val_step] = mnetspar_tmp/testimg.shape[0]
            val_step += 1
            if plot:
                visualization(randqual,mnetqual,greedyqual=greedyqual,\
                             randspar=randspar,mnetspar=mnetspar,greedyspar=greedyspar)
        global_step += 1
    # return mnet, unet

# %%
alternating_update_with_unetRecon(mnet,UNET,train_full,testimg,fullmask,\
                                  alpha=3e-4,c=1e-2,lr_mb=1e-4,lr_mn=1e-4,\
                                  maxIter_mb=50,maxRep=5,\
                                  corefreq=24,budget=24,\
                                  mask_greedy=mask_greedy,change_initmask=True,\
                                  verbose=True,plot=True)
# Out:
# /opt/anaconda/envs/pyenv/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # This is added back by InteractiveShellApp.init_path()
# iter: 1, upper level loss: 0.11603096127510071
# iter: 11, upper level loss: 0.11748206615447998
# iter: 21, upper level loss: 0.11280381679534912
# No change in row selections after 26 iters, ending iteration~
#
# return at Iter:  25
# loss of returned mask:  8.579153567552567
# Quality of random mask :  0.04341044
# Quality of mnet   mask :  0.040873405
# Quality of greedy mask :  0.042202625
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04271339
# Quality of mnet   mask :  0.038487166
# Quality of greedy mask :  0.042830553
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.036353614
# Quality of mnet   mask :  0.03417801
# Quality of greedy mask :  0.035620134
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03476612
# Quality of mnet   mask :  0.031814914
# Quality of greedy mask :  0.03234479
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.051378075
# Quality of mnet   mask :  0.046518337
# Quality of greedy mask :  0.04879248
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03778915
# Quality of mnet   mask :  0.032165214
# Quality of greedy mask :  0.032778665
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03331718
# Quality of mnet   mask :  0.02919447
# Quality of greedy mask :  0.030127533
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05744978
# Quality of mnet   mask :  0.050177574
# Quality of greedy mask :  0.052201208
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05133017
# Quality of mnet   mask :  0.046080425
# Quality of greedy mask :  0.048391037
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04390302
# Quality of mnet   mask :  0.037725504
# Quality of greedy mask :  0.042852312
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03933538
# Quality of mnet   mask :  0.03529396
# Quality of greedy mask :  0.036333445
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.040371373
# Quality of mnet   mask :  0.036652956
# Quality of greedy mask :  0.037640944
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.053276934
# Quality of mnet   mask :  0.045360606
# Quality of greedy mask :  0.050543956
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.044940192
# Quality of mnet   mask :  0.03887399
# Quality of greedy mask :  0.0408869
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.053826924
# Quality of mnet   mask :  0.04461092
# Quality of greedy mask :  0.04714303
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05029213
# Quality of mnet   mask :  0.04589045
# Quality of greedy mask :  0.045919448
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.070418686
# Quality of mnet   mask :  0.06504427
# Quality of greedy mask :  0.06859433
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05533786
# Quality of mnet   mask :  0.050954312
# Quality of greedy mask :  0.057082836
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05094925
# Quality of mnet   mask :  0.04593358
# Quality of greedy mask :  0.049722873
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.051688313
# Quality of mnet   mask :  0.044996344
# Quality of greedy mask :  0.049943764
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.056001905
# Quality of mnet   mask :  0.05093167
# Quality of greedy mask :  0.056068428
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05466654
# Quality of mnet   mask :  0.045894798
# Quality of greedy mask :  0.046237674
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05675286
# Quality of mnet   mask :  0.05017418
# Quality of greedy mask :  0.052684925
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05942719
# Quality of mnet   mask :  0.05064743
# Quality of greedy mask :  0.05625799
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.051477112
# Quality of mnet   mask :  0.04207958
# Quality of greedy mask :  0.04716816
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05164633
# Quality of mnet   mask :  0.044362877
# Quality of greedy mask :  0.04732028
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.0408968
# Quality of mnet   mask :  0.035130426
# Quality of greedy mask :  0.035481967
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03719222
# Quality of mnet   mask :  0.035271846
# Quality of greedy mask :  0.0367496
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.11059424
# Quality of mnet   mask :  0.11123997
# Quality of greedy mask :  0.111888334
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.045914818
# Quality of mnet   mask :  0.040058948
# Quality of greedy mask :  0.04199168
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043583963
# Quality of mnet   mask :  0.037723735
# Quality of greedy mask :  0.038837295
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04924736
# Quality of mnet   mask :  0.046728708
# Quality of greedy mask :  0.048846282
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.069192976
# Quality of mnet   mask :  0.057188354
# Quality of greedy mask :  0.059337705
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.055915717
# Quality of mnet   mask :  0.048131876
# Quality of greedy mask :  0.054285575
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
# Quality of random mask :  0.043423828
# Quality of mnet   mask :  0.04016779
# Quality of greedy mask :  0.042335857
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.041918766
# Quality of mnet   mask :  0.03607539
# Quality of greedy mask :  0.039511785
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.061731525
# Quality of mnet   mask :  0.057340767
# Quality of greedy mask :  0.059645902
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.044634994
# Quality of mnet   mask :  0.039523885
# Quality of greedy mask :  0.0413896
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05229468
# Quality of mnet   mask :  0.043474037
# Quality of greedy mask :  0.044798218
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.040533554
# Quality of mnet   mask :  0.035259385
# Quality of greedy mask :  0.04041854
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.047619384
# Quality of mnet   mask :  0.041404534
# Quality of greedy mask :  0.044838794
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.057101093
# Quality of mnet   mask :  0.054611836
# Quality of greedy mask :  0.05689665
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.049221747
# Quality of mnet   mask :  0.044053786
# Quality of greedy mask :  0.045305617
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05456749
# Quality of mnet   mask :  0.047418866
# Quality of greedy mask :  0.052110385
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.048229307
# Quality of mnet   mask :  0.041304033
# Quality of greedy mask :  0.046520833
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043958
# Quality of mnet   mask :  0.036796186
# Quality of greedy mask :  0.041315977
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05395103
# Quality of mnet   mask :  0.04525225
# Quality of greedy mask :  0.052863
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.07128773
# Quality of mnet   mask :  0.06556614
# Quality of greedy mask :  0.07070885
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05602049
# Quality of mnet   mask :  0.049516376
# Quality of greedy mask :  0.0534016
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.044981923
# Quality of mnet   mask :  0.03991809
# Quality of greedy mask :  0.03960604
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.041190755
# Quality of mnet   mask :  0.0353865
# Quality of greedy mask :  0.03717122
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05612375
# Quality of mnet   mask :  0.04513068
# Quality of greedy mask :  0.046518315
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.061525006
# Quality of mnet   mask :  0.05719669
# Quality of greedy mask :  0.060967244
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03197769
# Quality of mnet   mask :  0.028796641
# Quality of greedy mask :  0.030318122
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04594635
# Quality of mnet   mask :  0.04142208
# Quality of greedy mask :  0.0446083
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.07544328
# Quality of mnet   mask :  0.067271315
# Quality of greedy mask :  0.077513754
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.08278163
# Quality of mnet   mask :  0.07936535
# Quality of greedy mask :  0.090430304
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05013476
# Quality of mnet   mask :  0.044379994
# Quality of greedy mask :  0.04470058
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.055279143
# Quality of mnet   mask :  0.048963513
# Quality of greedy mask :  0.049774233
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05232661
# Quality of mnet   mask :  0.045232113
# Quality of greedy mask :  0.05148749
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.08248301
# Quality of mnet   mask :  0.07943881
# Quality of greedy mask :  0.08471663
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.050934758
# Quality of mnet   mask :  0.043481164
# Quality of greedy mask :  0.041911595
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03503934
# Quality of mnet   mask :  0.032179546
# Quality of greedy mask :  0.03380407
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.06777794
# Quality of mnet   mask :  0.060813736
# Quality of greedy mask :  0.06972435
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.055663593
# Quality of mnet   mask :  0.050546564
# Quality of greedy mask :  0.053806264
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.036987167
# Quality of mnet   mask :  0.034065697
# Quality of greedy mask :  0.0356531
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043055978
# Quality of mnet   mask :  0.036980614
# Quality of greedy mask :  0.03957666
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.035450194
# Quality of mnet   mask :  0.030692078
# Quality of greedy mask :  0.032063868
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.09758072
# Quality of mnet   mask :  0.095813386
# Quality of greedy mask :  0.10375962
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
# Quality of random mask :  0.035855584
# Quality of mnet   mask :  0.032993946
# Quality of greedy mask :  0.03361418
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043255758
# Quality of mnet   mask :  0.039322678
# Quality of greedy mask :  0.040763043
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.037938047
# Quality of mnet   mask :  0.03473854
# Quality of greedy mask :  0.034566958
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.07116424
# Quality of mnet   mask :  0.067716345
# Quality of greedy mask :  0.070376046
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.054528892
# Quality of mnet   mask :  0.048333712
# Quality of greedy mask :  0.049818702
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.042360306
# Quality of mnet   mask :  0.036629453
# Quality of greedy mask :  0.038684368
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05492022
# Quality of mnet   mask :  0.049392186
# Quality of greedy mask :  0.052593336
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.07791872
# Quality of mnet   mask :  0.07385804
# Quality of greedy mask :  0.081261665
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05070785
# Quality of mnet   mask :  0.045077793
# Quality of greedy mask :  0.045748144
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04817699
# Quality of mnet   mask :  0.04271502
# Quality of greedy mask :  0.04827221
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04467336
# Quality of mnet   mask :  0.035967693
# Quality of greedy mask :  0.041076664
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05683241
# Quality of mnet   mask :  0.052008078
# Quality of greedy mask :  0.058135387
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.0809429
# Quality of mnet   mask :  0.07809419
# Quality of greedy mask :  0.0841371
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05126931
# Quality of mnet   mask :  0.04393179
# Quality of greedy mask :  0.042742092
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.059413757
# Quality of mnet   mask :  0.053936295
# Quality of greedy mask :  0.056614347
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.055893227
# Quality of mnet   mask :  0.05169621
# Quality of greedy mask :  0.05461189
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05812003
# Quality of mnet   mask :  0.05141384
# Quality of greedy mask :  0.056175143
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.06259452
# Quality of mnet   mask :  0.055142146
# Quality of greedy mask :  0.059161887
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.059091475
# Quality of mnet   mask :  0.05286584
# Quality of greedy mask :  0.054508775
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04667876
# Quality of mnet   mask :  0.04257346
# Quality of greedy mask :  0.045116685
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.057009146
# Quality of mnet   mask :  0.049785886
# Quality of greedy mask :  0.050706565
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04473063
# Quality of mnet   mask :  0.04087891
# Quality of greedy mask :  0.040729195
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.055718366
# Quality of mnet   mask :  0.050195917
# Quality of greedy mask :  0.05650853
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043445136
# Quality of mnet   mask :  0.03978556
# Quality of greedy mask :  0.041314594
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04933107
# Quality of mnet   mask :  0.04045932
# Quality of greedy mask :  0.044157807
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05229461
# Quality of mnet   mask :  0.043279465
# Quality of greedy mask :  0.043057453
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.0396294
# Quality of mnet   mask :  0.034883726
# Quality of greedy mask :  0.037417576
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04313536
# Quality of mnet   mask :  0.03724132
# Quality of greedy mask :  0.03673364
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04843631
# Quality of mnet   mask :  0.042084426
# Quality of greedy mask :  0.046722997
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.040459033
# Quality of mnet   mask :  0.035427663
# Quality of greedy mask :  0.039417427
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04808528
# Quality of mnet   mask :  0.04209029
# Quality of greedy mask :  0.04380208
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.047436025
# Quality of mnet   mask :  0.041862983
# Quality of greedy mask :  0.0420478
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.050019134
# Quality of mnet   mask :  0.045336917
# Quality of greedy mask :  0.045852125
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.049817767
# Quality of mnet   mask :  0.042581078
# Quality of greedy mask :  0.04175977
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043509956
# Quality of mnet   mask :  0.04133073
# Quality of greedy mask :  0.044682663
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
# Quality of random mask :  0.05027946
# Quality of mnet   mask :  0.040549733
# Quality of greedy mask :  0.038129337
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04768773
# Quality of mnet   mask :  0.042565312
# Quality of greedy mask :  0.042496897
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03733534
# Quality of mnet   mask :  0.03422482
# Quality of greedy mask :  0.033380948
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.06887824
# Quality of mnet   mask :  0.06496736
# Quality of greedy mask :  0.06898052
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043056622
# Quality of mnet   mask :  0.03859475
# Quality of greedy mask :  0.03855825
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.054706983
# Quality of mnet   mask :  0.045629308
# Quality of greedy mask :  0.04879492
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.048455797
# Quality of mnet   mask :  0.04378149
# Quality of greedy mask :  0.047755264
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.07344586
# Quality of mnet   mask :  0.07208949
# Quality of greedy mask :  0.07880278
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04339357
# Quality of mnet   mask :  0.038344227
# Quality of greedy mask :  0.040066168
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.048308186
# Quality of mnet   mask :  0.044761837
# Quality of greedy mask :  0.05517379
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05090974
# Quality of mnet   mask :  0.043554258
# Quality of greedy mask :  0.0476828
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.047740176
# Quality of mnet   mask :  0.043540854
# Quality of greedy mask :  0.04799082
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043519456
# Quality of mnet   mask :  0.03910941
# Quality of greedy mask :  0.040509988
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.035547737
# Quality of mnet   mask :  0.033484407
# Quality of greedy mask :  0.033886276
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04287642
# Quality of mnet   mask :  0.036951132
# Quality of greedy mask :  0.039051373
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.049149256
# Quality of mnet   mask :  0.04249474
# Quality of greedy mask :  0.046953216
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04739017
# Quality of mnet   mask :  0.041190226
# Quality of greedy mask :  0.044065446
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04291603
# Quality of mnet   mask :  0.039249048
# Quality of greedy mask :  0.041404333
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04471305
# Quality of mnet   mask :  0.038869835
# Quality of greedy mask :  0.04189448
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.049215402
# Quality of mnet   mask :  0.043704536
# Quality of greedy mask :  0.047598053
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05306434
# Quality of mnet   mask :  0.044689212
# Quality of greedy mask :  0.051543195
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05236916
# Quality of mnet   mask :  0.049717497
# Quality of greedy mask :  0.05155621
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.08256
# Quality of mnet   mask :  0.07905674
# Quality of greedy mask :  0.086252324
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.055028316
# Quality of mnet   mask :  0.04876598
# Quality of greedy mask :  0.05193485
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.057499837
# Quality of mnet   mask :  0.049689956
# Quality of greedy mask :  0.04973805
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.051412843
# Quality of mnet   mask :  0.04716256
# Quality of greedy mask :  0.05057382
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.040776003
# Quality of mnet   mask :  0.034574885
# Quality of greedy mask :  0.038348436
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04007952
# Quality of mnet   mask :  0.035258584
# Quality of greedy mask :  0.036147486
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.048063945
# Quality of mnet   mask :  0.041426394
# Quality of greedy mask :  0.04230712
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.052676216
# Quality of mnet   mask :  0.043912694
# Quality of greedy mask :  0.048196636
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.056136962
# Quality of mnet   mask :  0.049398873
# Quality of greedy mask :  0.05424819
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.052615974
# Quality of mnet   mask :  0.04629327
# Quality of greedy mask :  0.047219887
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04979368
# Quality of mnet   mask :  0.043762814
# Quality of greedy mask :  0.04729817
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.058924105
# Quality of mnet   mask :  0.051148526
# Quality of greedy mask :  0.057065416
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04109215
# Quality of mnet   mask :  0.03791471
# Quality of greedy mask :  0.039220735
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
# Quality of random mask :  0.05886653
# Quality of mnet   mask :  0.050981663
# Quality of greedy mask :  0.054677565
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043128923
# Quality of mnet   mask :  0.03950486
# Quality of greedy mask :  0.04306116
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.038406033
# Quality of mnet   mask :  0.035201535
# Quality of greedy mask :  0.0368082
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043064523
# Quality of mnet   mask :  0.039572775
# Quality of greedy mask :  0.0407781
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.040290408
# Quality of mnet   mask :  0.036471456
# Quality of greedy mask :  0.03762397
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05654833
# Quality of mnet   mask :  0.05061787
# Quality of greedy mask :  0.057072368
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.048770655
# Quality of mnet   mask :  0.04312891
# Quality of greedy mask :  0.047914326
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05046491
# Quality of mnet   mask :  0.04456334
# Quality of greedy mask :  0.04840646
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.053567518
# Quality of mnet   mask :  0.049884208
# Quality of greedy mask :  0.05396015
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043924257
# Quality of mnet   mask :  0.039424084
# Quality of greedy mask :  0.039383426
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.041323557
# Quality of mnet   mask :  0.038094483
# Quality of greedy mask :  0.04022922
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05106206
# Quality of mnet   mask :  0.04323742
# Quality of greedy mask :  0.044094745
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03837439
# Quality of mnet   mask :  0.035246648
# Quality of greedy mask :  0.034453496
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.08876699
# Quality of mnet   mask :  0.08570152
# Quality of greedy mask :  0.09213744
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04980369
# Quality of mnet   mask :  0.046225507
# Quality of greedy mask :  0.049809206
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.0366061
# Quality of mnet   mask :  0.032099664
# Quality of greedy mask :  0.033136774
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.054041836
# Quality of mnet   mask :  0.050222263
# Quality of greedy mask :  0.052382097
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04779424
# Quality of mnet   mask :  0.042160016
# Quality of greedy mask :  0.040498715
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03689043
# Quality of mnet   mask :  0.031695258
# Quality of greedy mask :  0.0318507
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.055724274
# Quality of mnet   mask :  0.048385885
# Quality of greedy mask :  0.051574625
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.039912015
# Quality of mnet   mask :  0.035351943
# Quality of greedy mask :  0.037183367
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.032466833
# Quality of mnet   mask :  0.02955682
# Quality of greedy mask :  0.030435385
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.044142585
# Quality of mnet   mask :  0.039565183
# Quality of greedy mask :  0.042845722
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05503696
# Quality of mnet   mask :  0.048494082
# Quality of greedy mask :  0.050522693
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.053069953
# Quality of mnet   mask :  0.046914864
# Quality of greedy mask :  0.047849882
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.048385967
# Quality of mnet   mask :  0.04203016
# Quality of greedy mask :  0.041341923
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.06300378
# Quality of mnet   mask :  0.052475844
# Quality of greedy mask :  0.053409215
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.06672799
# Quality of mnet   mask :  0.063988246
# Quality of greedy mask :  0.07017609
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.052773993
# Quality of mnet   mask :  0.047220234
# Quality of greedy mask :  0.05144842
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.055999093
# Quality of mnet   mask :  0.048816912
# Quality of greedy mask :  0.05449935
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.039822664
# Quality of mnet   mask :  0.033908628
# Quality of greedy mask :  0.03433743
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.03784802
# Quality of mnet   mask :  0.0355025
# Quality of greedy mask :  0.037050523
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04089574
# Quality of mnet   mask :  0.038586825
# Quality of greedy mask :  0.040746585
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.045102585
# Quality of mnet   mask :  0.039821744
# Quality of greedy mask :  0.045159835
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04067843
# Quality of mnet   mask :  0.036960192
# Quality of greedy mask :  0.0401567
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
# Quality of random mask :  0.05845699
# Quality of mnet   mask :  0.05062435
# Quality of greedy mask :  0.052226402
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04910817
# Quality of mnet   mask :  0.04463888
# Quality of greedy mask :  0.043639235
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05563865
# Quality of mnet   mask :  0.048171103
# Quality of greedy mask :  0.050713256
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.058347654
# Quality of mnet   mask :  0.048510794
# Quality of greedy mask :  0.052717786
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.067285754
# Quality of mnet   mask :  0.056244448
# Quality of greedy mask :  0.06504103
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04318134
# Quality of mnet   mask :  0.03698158
# Quality of greedy mask :  0.037979852
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.06289976
# Quality of mnet   mask :  0.057490442
# Quality of greedy mask :  0.059929945
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.043760814
# Quality of mnet   mask :  0.038532585
# Quality of greedy mask :  0.04130372
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.05104983
# Quality of mnet   mask :  0.045729123
# Quality of greedy mask :  0.04804772
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.051781118
# Quality of mnet   mask :  0.045593053
# Quality of greedy mask :  0.049342718
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.058878493
# Quality of mnet   mask :  0.051388137
# Quality of greedy mask :  0.059260022
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.036739238
# Quality of mnet   mask :  0.03378465
# Quality of greedy mask :  0.03479669
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.037009444
# Quality of mnet   mask :  0.034294393
# Quality of greedy mask :  0.03554454
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.051262278
# Quality of mnet   mask :  0.04400112
# Quality of greedy mask :  0.043782786
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.0558584
# Quality of mnet   mask :  0.04833645
# Quality of greedy mask :  0.05032348
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.050680667
# Quality of mnet   mask :  0.044247165
# Quality of greedy mask :  0.04238232
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.07726816
# Quality of mnet   mask :  0.0756538
# Quality of greedy mask :  0.08464396
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.06337974
# Quality of mnet   mask :  0.059513927
# Quality of greedy mask :  0.0641982
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04526311
# Quality of mnet   mask :  0.040043626
# Quality of greedy mask :  0.040627982
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.042180985
# Quality of mnet   mask :  0.036989167
# Quality of greedy mask :  0.039885513
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.04083703
# Quality of mnet   mask :  0.03588497
# Quality of greedy mask :  0.03702985
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.063691065
# Quality of mnet   mask :  0.054190747
# Quality of greedy mask :  0.055704236
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.060857672
# Quality of mnet   mask :  0.052046698
# Quality of greedy mask :  0.053171538
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.054286476
# Quality of mnet   mask :  0.051776532
# Quality of greedy mask :  0.054887917
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
#
#
# Quality of random mask :  0.051748544
# Quality of mnet   mask :  0.046732634
# Quality of greedy mask :  0.04641216
# sparsity of random mask: 0.15,                            mnet mask: 0.15,                             greedy mask: 0.25
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-7c2de9d69e85> in <module>
#       4                                   corefreq=24,budget=24,\
#       5                                   mask_greedy=mask_greedy,change_initmask=True,\
# ----> 6                                   verbose=True,plot=True)
#
# <ipython-input-21-c3356e101dba> in alternating_update_with_unetRecon(mnet, unet, trainfulls, testimg, mask_init, mask_init_full, maxIter_mb, evalmode, alpha, c, lr_mb, lr_mn, maxRep, corefreq, budget, plot, verbose, mask_greedy, change_initmask, validate_every, dtyp)
#     117             val_step += 1
#     118             if plot:
# --> 119                 visulization(randqual,mnetqual,greedyqual=greedyqual,\
#     120                              randspar=randspar,mnetspar=mnetspar,greedyspar=greedyspar)
#     121         global_step += 1
#
# NameError: name 'visulization' is not defined

# %%
reload(utils)
import mask_backward_new
reload(mask_backward_new)
from mask_backward_new import mask_backward
from utils import raw_normalize
